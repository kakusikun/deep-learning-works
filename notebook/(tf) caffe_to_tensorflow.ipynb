# %%
import sys
sys.path.insert(0, "/home/allen/Documents/caffe/python")
import caffe
import numpy as np

import caffe.proto.caffe_pb2 as caffepb
from google.protobuf import text_format
import tensorflow as tf

# %%
import os
import sys
sys.path.insert(0, "/media/allen/mass/deep-learning-works/")
from model.managers.manager_gae import Model, GAE
from model.MobileNetv1 import MobileNetv1

# %%
net = Model(num_classes=[1,101,3], model_name="gae")

# %%
net.convert_to_caffe(name='GAE', path="../caffe_models/", input_size=[1,3,112,112])
# Out:
# layer {
#   name: "data"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 1
#       dim: 3
#       dim: 112
#       dim: 112
#     }
#   }
# }
# layer {
#   name: "conv0"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv0"
#   convolution_param {
#     num_output: 32
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 1
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv0/bn"
#   type: "BatchNorm"
#   bottom: "conv0"
#   top: "conv0/bn"
# }
# layer {
#   name: "conv0/bn/scale"
#   type: "Scale"
#   bottom: "conv0/bn"
#   top: "conv0/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv0/relu"
#   type: "ReLU"
#   bottom: "conv0/bn"
#   top: "conv0/relu"
# }
# layer {
#   name: "conv1/dw"
#   type: "Convolution"
#   bottom: "conv0/relu"
#   top: "conv1/dw"
#   convolution_param {
#     num_output: 32
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 32
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv1/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv1/dw"
#   top: "conv1/dw/bn"
# }
# layer {
#   name: "conv1/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv1/dw/bn"
#   top: "conv1/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv1/dw/relu"
#   type: "ReLU"
#   bottom: "conv1/dw/bn"
#   top: "conv1/dw/relu"
# }
# layer {
#   name: "conv1/sep"
#   type: "Convolution"
#   bottom: "conv1/dw/relu"
#   top: "conv1/sep"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv1/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv1/sep"
#   top: "conv1/sep/bn"
# }
# layer {
#   name: "conv1/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv1/sep/bn"
#   top: "conv1/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv1/sep/relu"
#   type: "ReLU"
#   bottom: "conv1/sep/bn"
#   top: "conv1/sep/relu"
# }
# layer {
#   name: "conv2/dw"
#   type: "Convolution"
#   bottom: "conv1/sep/relu"
#   top: "conv2/dw"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 64
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv2/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv2/dw"
#   top: "conv2/dw/bn"
# }
# layer {
#   name: "conv2/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv2/dw/bn"
#   top: "conv2/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv2/dw/relu"
#   type: "ReLU"
#   bottom: "conv2/dw/bn"
#   top: "conv2/dw/relu"
# }
# layer {
#   name: "conv2/sep"
#   type: "Convolution"
#   bottom: "conv2/dw/relu"
#   top: "conv2/sep"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv2/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv2/sep"
#   top: "conv2/sep/bn"
# }
# layer {
#   name: "conv2/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv2/sep/bn"
#   top: "conv2/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv2/sep/relu"
#   type: "ReLU"
#   bottom: "conv2/sep/bn"
#   top: "conv2/sep/relu"
# }
# layer {
#   name: "conv3/dw"
#   type: "Convolution"
#   bottom: "conv2/sep/relu"
#   top: "conv3/dw"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 128
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv3/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv3/dw"
#   top: "conv3/dw/bn"
# }
# layer {
#   name: "conv3/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv3/dw/bn"
#   top: "conv3/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv3/dw/relu"
#   type: "ReLU"
#   bottom: "conv3/dw/bn"
#   top: "conv3/dw/relu"
# }
# layer {
#   name: "conv3/sep"
#   type: "Convolution"
#   bottom: "conv3/dw/relu"
#   top: "conv3/sep"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv3/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv3/sep"
#   top: "conv3/sep/bn"
# }
# layer {
#   name: "conv3/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv3/sep/bn"
#   top: "conv3/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv3/sep/relu"
#   type: "ReLU"
#   bottom: "conv3/sep/bn"
#   top: "conv3/sep/relu"
# }
# layer {
#   name: "conv4/dw"
#   type: "Convolution"
#   bottom: "conv3/sep/relu"
#   top: "conv4/dw"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 128
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv4/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv4/dw"
#   top: "conv4/dw/bn"
# }
# layer {
#   name: "conv4/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv4/dw/bn"
#   top: "conv4/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv4/dw/relu"
#   type: "ReLU"
#   bottom: "conv4/dw/bn"
#   top: "conv4/dw/relu"
# }
# layer {
#   name: "conv4/sep"
#   type: "Convolution"
#   bottom: "conv4/dw/relu"
#   top: "conv4/sep"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv4/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv4/sep"
#   top: "conv4/sep/bn"
# }
# layer {
#   name: "conv4/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv4/sep/bn"
#   top: "conv4/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv4/sep/relu"
#   type: "ReLU"
#   bottom: "conv4/sep/bn"
#   top: "conv4/sep/relu"
# }
# layer {
#   name: "conv5/dw"
#   type: "Convolution"
#   bottom: "conv4/sep/relu"
#   top: "conv5/dw"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 256
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv5/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv5/dw"
#   top: "conv5/dw/bn"
# }
# layer {
#   name: "conv5/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv5/dw/bn"
#   top: "conv5/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv5/dw/relu"
#   type: "ReLU"
#   bottom: "conv5/dw/bn"
#   top: "conv5/dw/relu"
# }
# layer {
#   name: "conv5/sep"
#   type: "Convolution"
#   bottom: "conv5/dw/relu"
#   top: "conv5/sep"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv5/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv5/sep"
#   top: "conv5/sep/bn"
# }
# layer {
#   name: "conv5/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv5/sep/bn"
#   top: "conv5/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv5/sep/relu"
#   type: "ReLU"
#   bottom: "conv5/sep/bn"
#   top: "conv5/sep/relu"
# }
# layer {
#   name: "conv6/dw"
#   type: "Convolution"
#   bottom: "conv5/sep/relu"
#   top: "conv6/dw"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 256
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv6/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv6/dw"
#   top: "conv6/dw/bn"
# }
# layer {
#   name: "conv6/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv6/dw/bn"
#   top: "conv6/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv6/dw/relu"
#   type: "ReLU"
#   bottom: "conv6/dw/bn"
#   top: "conv6/dw/relu"
# }
# layer {
#   name: "conv6/sep"
#   type: "Convolution"
#   bottom: "conv6/dw/relu"
#   top: "conv6/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv6/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv6/sep"
#   top: "conv6/sep/bn"
# }
# layer {
#   name: "conv6/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv6/sep/bn"
#   top: "conv6/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv6/sep/relu"
#   type: "ReLU"
#   bottom: "conv6/sep/bn"
#   top: "conv6/sep/relu"
# }
# layer {
#   name: "conv7/dw"
#   type: "Convolution"
#   bottom: "conv6/sep/relu"
#   top: "conv7/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv7/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv7/dw"
#   top: "conv7/dw/bn"
# }
# layer {
#   name: "conv7/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv7/dw/bn"
#   top: "conv7/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv7/dw/relu"
#   type: "ReLU"
#   bottom: "conv7/dw/bn"
#   top: "conv7/dw/relu"
# }
# layer {
#   name: "conv7/sep"
#   type: "Convolution"
#   bottom: "conv7/dw/relu"
#   top: "conv7/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv7/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv7/sep"
#   top: "conv7/sep/bn"
# }
# layer {
#   name: "conv7/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv7/sep/bn"
#   top: "conv7/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv7/sep/relu"
#   type: "ReLU"
#   bottom: "conv7/sep/bn"
#   top: "conv7/sep/relu"
# }
# layer {
#   name: "conv8/dw"
#   type: "Convolution"
#   bottom: "conv7/sep/relu"
#   top: "conv8/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv8/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv8/dw"
#   top: "conv8/dw/bn"
# }
# layer {
#   name: "conv8/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv8/dw/bn"
#   top: "conv8/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv8/dw/relu"
#   type: "ReLU"
#   bottom: "conv8/dw/bn"
#   top: "conv8/dw/relu"
# }
# layer {
#   name: "conv8/sep"
#   type: "Convolution"
#   bottom: "conv8/dw/relu"
#   top: "conv8/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv8/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv8/sep"
#   top: "conv8/sep/bn"
# }
# layer {
#   name: "conv8/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv8/sep/bn"
#   top: "conv8/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv8/sep/relu"
#   type: "ReLU"
#   bottom: "conv8/sep/bn"
#   top: "conv8/sep/relu"
# }
# layer {
#   name: "conv9/dw"
#   type: "Convolution"
#   bottom: "conv8/sep/relu"
#   top: "conv9/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv9/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv9/dw"
#   top: "conv9/dw/bn"
# }
# layer {
#   name: "conv9/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv9/dw/bn"
#   top: "conv9/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv9/dw/relu"
#   type: "ReLU"
#   bottom: "conv9/dw/bn"
#   top: "conv9/dw/relu"
# }
# layer {
#   name: "conv9/sep"
#   type: "Convolution"
#   bottom: "conv9/dw/relu"
#   top: "conv9/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv9/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv9/sep"
#   top: "conv9/sep/bn"
# }
# layer {
#   name: "conv9/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv9/sep/bn"
#   top: "conv9/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv9/sep/relu"
#   type: "ReLU"
#   bottom: "conv9/sep/bn"
#   top: "conv9/sep/relu"
# }
# layer {
#   name: "conv10/dw"
#   type: "Convolution"
#   bottom: "conv9/sep/relu"
#   top: "conv10/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv10/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv10/dw"
#   top: "conv10/dw/bn"
# }
# layer {
#   name: "conv10/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv10/dw/bn"
#   top: "conv10/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv10/dw/relu"
#   type: "ReLU"
#   bottom: "conv10/dw/bn"
#   top: "conv10/dw/relu"
# }
# layer {
#   name: "conv10/sep"
#   type: "Convolution"
#   bottom: "conv10/dw/relu"
#   top: "conv10/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv10/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv10/sep"
#   top: "conv10/sep/bn"
# }
# layer {
#   name: "conv10/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv10/sep/bn"
#   top: "conv10/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv10/sep/relu"
#   type: "ReLU"
#   bottom: "conv10/sep/bn"
#   top: "conv10/sep/relu"
# }
# layer {
#   name: "conv11/dw"
#   type: "Convolution"
#   bottom: "conv10/sep/relu"
#   top: "conv11/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv11/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv11/dw"
#   top: "conv11/dw/bn"
# }
# layer {
#   name: "conv11/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv11/dw/bn"
#   top: "conv11/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv11/dw/relu"
#   type: "ReLU"
#   bottom: "conv11/dw/bn"
#   top: "conv11/dw/relu"
# }
# layer {
#   name: "conv11/sep"
#   type: "Convolution"
#   bottom: "conv11/dw/relu"
#   top: "conv11/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv11/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv11/sep"
#   top: "conv11/sep/bn"
# }
# layer {
#   name: "conv11/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv11/sep/bn"
#   top: "conv11/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv11/sep/relu"
#   type: "ReLU"
#   bottom: "conv11/sep/bn"
#   top: "conv11/sep/relu"
# }
# layer {
#   name: "conv12/dw"
#   type: "Convolution"
#   bottom: "conv11/sep/relu"
#   top: "conv12/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv12/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv12/dw"
#   top: "conv12/dw/bn"
# }
# layer {
#   name: "conv12/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv12/dw/bn"
#   top: "conv12/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv12/dw/relu"
#   type: "ReLU"
#   bottom: "conv12/dw/bn"
#   top: "conv12/dw/relu"
# }
# layer {
#   name: "conv12/sep"
#   type: "Convolution"
#   bottom: "conv12/dw/relu"
#   top: "conv12/sep"
#   convolution_param {
#     num_output: 1024
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv12/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv12/sep"
#   top: "conv12/sep/bn"
# }
# layer {
#   name: "conv12/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv12/sep/bn"
#   top: "conv12/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv12/sep/relu"
#   type: "ReLU"
#   bottom: "conv12/sep/bn"
#   top: "conv12/sep/relu"
# }
# layer {
#   name: "conv13/dw"
#   type: "Convolution"
#   bottom: "conv12/sep/relu"
#   top: "conv13/dw"
#   convolution_param {
#     num_output: 1024
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 1024
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv13/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv13/dw"
#   top: "conv13/dw/bn"
# }
# layer {
#   name: "conv13/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv13/dw/bn"
#   top: "conv13/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv13/dw/relu"
#   type: "ReLU"
#   bottom: "conv13/dw/bn"
#   top: "conv13/dw/relu"
# }
# layer {
#   name: "conv13/sep"
#   type: "Convolution"
#   bottom: "conv13/dw/relu"
#   top: "conv13/sep"
#   convolution_param {
#     num_output: 1024
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv13/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv13/sep"
#   top: "conv13/sep/bn"
# }
# layer {
#   name: "conv13/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv13/sep/bn"
#   top: "conv13/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv13/sep/relu"
#   type: "ReLU"
#   bottom: "conv13/sep/bn"
#   top: "conv13/sep/relu"
# }
# layer {
#   name: "reshape"
#   type: "Flatten"
#   bottom: "conv13/sep/relu"
#   top: "reshape"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "gender"
#   type: "InnerProduct"
#   bottom: "reshape"
#   top: "gender"
#   inner_product_param {
#     num_output: 1
#     bias_term: true
#   }
# }
# layer {
#   name: "sigmoid"
#   type: "Sigmoid"
#   bottom: "gender"
#   top: "sigmoid"
# }
# layer {
#   name: "age"
#   type: "InnerProduct"
#   bottom: "reshape"
#   top: "age"
#   inner_product_param {
#     num_output: 101
#     bias_term: true
#   }
# }
# layer {
#   name: "emotion"
#   type: "InnerProduct"
#   bottom: "reshape"
#   top: "emotion"
#   inner_product_param {
#     num_output: 3
#     bias_term: true
#   }
# }
# convert conv: backbone.model.0.0 conv0 Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# convert bn: backbone.model.0.1 conv0/bn BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.1.0.0 conv1/dw Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
# convert bn: backbone.model.1.0.1 conv1/dw/bn BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.1.1.0 conv1/sep Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.1.1.1 conv1/sep/bn BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.2.0.0 conv2/dw Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
# convert bn: backbone.model.2.0.1 conv2/dw/bn BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.2.1.0 conv2/sep Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.2.1.1 conv2/sep/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.3.0.0 conv3/dw Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
# convert bn: backbone.model.3.0.1 conv3/dw/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.3.1.0 conv3/sep Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.3.1.1 conv3/sep/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.4.0.0 conv4/dw Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
# convert bn: backbone.model.4.0.1 conv4/dw/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.4.1.0 conv4/sep Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.4.1.1 conv4/sep/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.5.0.0 conv5/dw Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
# convert bn: backbone.model.5.0.1 conv5/dw/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.5.1.0 conv5/sep Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.5.1.1 conv5/sep/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.6.0.0 conv6/dw Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
# convert bn: backbone.model.6.0.1 conv6/dw/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.6.1.0 conv6/sep Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.6.1.1 conv6/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.7.0.0 conv7/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: backbone.model.7.0.1 conv7/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.7.1.0 conv7/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.7.1.1 conv7/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.8.0.0 conv8/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: backbone.model.8.0.1 conv8/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.8.1.0 conv8/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.8.1.1 conv8/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.9.0.0 conv9/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: backbone.model.9.0.1 conv9/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.9.1.0 conv9/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.9.1.1 conv9/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.10.0.0 conv10/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: backbone.model.10.0.1 conv10/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.10.1.0 conv10/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.10.1.1 conv10/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.11.0.0 conv11/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: backbone.model.11.0.1 conv11/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.11.1.0 conv11/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.11.1.1 conv11/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.12.0.0 conv12/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512, bias=False)
# convert bn: backbone.model.12.0.1 conv12/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.12.1.0 conv12/sep Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.12.1.1 conv12/sep/bn BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.13.0.0 conv13/dw Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
# convert bn: backbone.model.13.0.1 conv13/dw/bn BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: backbone.model.13.1.0 conv13/sep Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: backbone.model.13.1.1 conv13/sep/bn BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert fc: gae.gender gender Linear(in_features=16384, out_features=1, bias=True)
# convert fc: gae.age age Linear(in_features=16384, out_features=101, bias=True)
# convert fc: gae.emotion emotion Linear(in_features=16384, out_features=3, bias=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-49bacbe7e6a8> in <module>()
# ----> 1 net.convert_to_caffe(name='GAE', path="../caffe_models/", input_size=[1,3,112,112])
#
# /media/allen/mass/deep-learning-works/model/managers/manager_gae.py in convert_to_caffe(self, name, path, input_size)
#     156         caffe_net.blobs['data'].data[...] = img.copy()
#     157         caffe_results = caffe_net.forward()
# --> 158         gender_caffe, age_caffe, emotion_caffe = caffe_results['gender'], caffe_results['age'], caffe_results['emotion']
#     159
#     160         assert_diff(gender, gender_caffe)
#
# KeyError: 'gender'

# %%
alpha=1.0
net = MobileNetv1(num_classes=200, alpha=alpha)

net.convert_to_caffe(name='MobileNetV1_{}'.format(alpha), path="../caffe_models/", input_size=[1,3,112,112])
# Out:
# layer {
#   name: "data"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 1
#       dim: 3
#       dim: 112
#       dim: 112
#     }
#   }
# }
# layer {
#   name: "conv0"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv0"
#   convolution_param {
#     num_output: 32
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 1
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv0/bn"
#   type: "BatchNorm"
#   bottom: "conv0"
#   top: "conv0/bn"
# }
# layer {
#   name: "conv0/bn/scale"
#   type: "Scale"
#   bottom: "conv0/bn"
#   top: "conv0/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv0/relu"
#   type: "ReLU"
#   bottom: "conv0/bn"
#   top: "conv0/relu"
# }
# layer {
#   name: "conv1/dw"
#   type: "Convolution"
#   bottom: "conv0/relu"
#   top: "conv1/dw"
#   convolution_param {
#     num_output: 32
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 32
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv1/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv1/dw"
#   top: "conv1/dw/bn"
# }
# layer {
#   name: "conv1/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv1/dw/bn"
#   top: "conv1/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv1/dw/relu"
#   type: "ReLU"
#   bottom: "conv1/dw/bn"
#   top: "conv1/dw/relu"
# }
# layer {
#   name: "conv1/sep"
#   type: "Convolution"
#   bottom: "conv1/dw/relu"
#   top: "conv1/sep"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv1/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv1/sep"
#   top: "conv1/sep/bn"
# }
# layer {
#   name: "conv1/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv1/sep/bn"
#   top: "conv1/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv1/sep/relu"
#   type: "ReLU"
#   bottom: "conv1/sep/bn"
#   top: "conv1/sep/relu"
# }
# layer {
#   name: "conv2/dw"
#   type: "Convolution"
#   bottom: "conv1/sep/relu"
#   top: "conv2/dw"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 64
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv2/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv2/dw"
#   top: "conv2/dw/bn"
# }
# layer {
#   name: "conv2/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv2/dw/bn"
#   top: "conv2/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv2/dw/relu"
#   type: "ReLU"
#   bottom: "conv2/dw/bn"
#   top: "conv2/dw/relu"
# }
# layer {
#   name: "conv2/sep"
#   type: "Convolution"
#   bottom: "conv2/dw/relu"
#   top: "conv2/sep"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv2/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv2/sep"
#   top: "conv2/sep/bn"
# }
# layer {
#   name: "conv2/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv2/sep/bn"
#   top: "conv2/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv2/sep/relu"
#   type: "ReLU"
#   bottom: "conv2/sep/bn"
#   top: "conv2/sep/relu"
# }
# layer {
#   name: "conv3/dw"
#   type: "Convolution"
#   bottom: "conv2/sep/relu"
#   top: "conv3/dw"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 128
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv3/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv3/dw"
#   top: "conv3/dw/bn"
# }
# layer {
#   name: "conv3/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv3/dw/bn"
#   top: "conv3/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv3/dw/relu"
#   type: "ReLU"
#   bottom: "conv3/dw/bn"
#   top: "conv3/dw/relu"
# }
# layer {
#   name: "conv3/sep"
#   type: "Convolution"
#   bottom: "conv3/dw/relu"
#   top: "conv3/sep"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv3/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv3/sep"
#   top: "conv3/sep/bn"
# }
# layer {
#   name: "conv3/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv3/sep/bn"
#   top: "conv3/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv3/sep/relu"
#   type: "ReLU"
#   bottom: "conv3/sep/bn"
#   top: "conv3/sep/relu"
# }
# layer {
#   name: "conv4/dw"
#   type: "Convolution"
#   bottom: "conv3/sep/relu"
#   top: "conv4/dw"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 128
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv4/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv4/dw"
#   top: "conv4/dw/bn"
# }
# layer {
#   name: "conv4/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv4/dw/bn"
#   top: "conv4/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv4/dw/relu"
#   type: "ReLU"
#   bottom: "conv4/dw/bn"
#   top: "conv4/dw/relu"
# }
# layer {
#   name: "conv4/sep"
#   type: "Convolution"
#   bottom: "conv4/dw/relu"
#   top: "conv4/sep"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv4/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv4/sep"
#   top: "conv4/sep/bn"
# }
# layer {
#   name: "conv4/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv4/sep/bn"
#   top: "conv4/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv4/sep/relu"
#   type: "ReLU"
#   bottom: "conv4/sep/bn"
#   top: "conv4/sep/relu"
# }
# layer {
#   name: "conv5/dw"
#   type: "Convolution"
#   bottom: "conv4/sep/relu"
#   top: "conv5/dw"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 256
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv5/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv5/dw"
#   top: "conv5/dw/bn"
# }
# layer {
#   name: "conv5/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv5/dw/bn"
#   top: "conv5/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv5/dw/relu"
#   type: "ReLU"
#   bottom: "conv5/dw/bn"
#   top: "conv5/dw/relu"
# }
# layer {
#   name: "conv5/sep"
#   type: "Convolution"
#   bottom: "conv5/dw/relu"
#   top: "conv5/sep"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv5/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv5/sep"
#   top: "conv5/sep/bn"
# }
# layer {
#   name: "conv5/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv5/sep/bn"
#   top: "conv5/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv5/sep/relu"
#   type: "ReLU"
#   bottom: "conv5/sep/bn"
#   top: "conv5/sep/relu"
# }
# layer {
#   name: "conv6/dw"
#   type: "Convolution"
#   bottom: "conv5/sep/relu"
#   top: "conv6/dw"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 256
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv6/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv6/dw"
#   top: "conv6/dw/bn"
# }
# layer {
#   name: "conv6/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv6/dw/bn"
#   top: "conv6/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv6/dw/relu"
#   type: "ReLU"
#   bottom: "conv6/dw/bn"
#   top: "conv6/dw/relu"
# }
# layer {
#   name: "conv6/sep"
#   type: "Convolution"
#   bottom: "conv6/dw/relu"
#   top: "conv6/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv6/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv6/sep"
#   top: "conv6/sep/bn"
# }
# layer {
#   name: "conv6/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv6/sep/bn"
#   top: "conv6/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv6/sep/relu"
#   type: "ReLU"
#   bottom: "conv6/sep/bn"
#   top: "conv6/sep/relu"
# }
# layer {
#   name: "conv7/dw"
#   type: "Convolution"
#   bottom: "conv6/sep/relu"
#   top: "conv7/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv7/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv7/dw"
#   top: "conv7/dw/bn"
# }
# layer {
#   name: "conv7/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv7/dw/bn"
#   top: "conv7/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv7/dw/relu"
#   type: "ReLU"
#   bottom: "conv7/dw/bn"
#   top: "conv7/dw/relu"
# }
# layer {
#   name: "conv7/sep"
#   type: "Convolution"
#   bottom: "conv7/dw/relu"
#   top: "conv7/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv7/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv7/sep"
#   top: "conv7/sep/bn"
# }
# layer {
#   name: "conv7/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv7/sep/bn"
#   top: "conv7/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv7/sep/relu"
#   type: "ReLU"
#   bottom: "conv7/sep/bn"
#   top: "conv7/sep/relu"
# }
# layer {
#   name: "conv8/dw"
#   type: "Convolution"
#   bottom: "conv7/sep/relu"
#   top: "conv8/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv8/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv8/dw"
#   top: "conv8/dw/bn"
# }
# layer {
#   name: "conv8/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv8/dw/bn"
#   top: "conv8/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv8/dw/relu"
#   type: "ReLU"
#   bottom: "conv8/dw/bn"
#   top: "conv8/dw/relu"
# }
# layer {
#   name: "conv8/sep"
#   type: "Convolution"
#   bottom: "conv8/dw/relu"
#   top: "conv8/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv8/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv8/sep"
#   top: "conv8/sep/bn"
# }
# layer {
#   name: "conv8/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv8/sep/bn"
#   top: "conv8/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv8/sep/relu"
#   type: "ReLU"
#   bottom: "conv8/sep/bn"
#   top: "conv8/sep/relu"
# }
# layer {
#   name: "conv9/dw"
#   type: "Convolution"
#   bottom: "conv8/sep/relu"
#   top: "conv9/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv9/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv9/dw"
#   top: "conv9/dw/bn"
# }
# layer {
#   name: "conv9/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv9/dw/bn"
#   top: "conv9/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv9/dw/relu"
#   type: "ReLU"
#   bottom: "conv9/dw/bn"
#   top: "conv9/dw/relu"
# }
# layer {
#   name: "conv9/sep"
#   type: "Convolution"
#   bottom: "conv9/dw/relu"
#   top: "conv9/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv9/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv9/sep"
#   top: "conv9/sep/bn"
# }
# layer {
#   name: "conv9/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv9/sep/bn"
#   top: "conv9/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv9/sep/relu"
#   type: "ReLU"
#   bottom: "conv9/sep/bn"
#   top: "conv9/sep/relu"
# }
# layer {
#   name: "conv10/dw"
#   type: "Convolution"
#   bottom: "conv9/sep/relu"
#   top: "conv10/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv10/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv10/dw"
#   top: "conv10/dw/bn"
# }
# layer {
#   name: "conv10/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv10/dw/bn"
#   top: "conv10/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv10/dw/relu"
#   type: "ReLU"
#   bottom: "conv10/dw/bn"
#   top: "conv10/dw/relu"
# }
# layer {
#   name: "conv10/sep"
#   type: "Convolution"
#   bottom: "conv10/dw/relu"
#   top: "conv10/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv10/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv10/sep"
#   top: "conv10/sep/bn"
# }
# layer {
#   name: "conv10/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv10/sep/bn"
#   top: "conv10/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv10/sep/relu"
#   type: "ReLU"
#   bottom: "conv10/sep/bn"
#   top: "conv10/sep/relu"
# }
# layer {
#   name: "conv11/dw"
#   type: "Convolution"
#   bottom: "conv10/sep/relu"
#   top: "conv11/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv11/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv11/dw"
#   top: "conv11/dw/bn"
# }
# layer {
#   name: "conv11/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv11/dw/bn"
#   top: "conv11/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv11/dw/relu"
#   type: "ReLU"
#   bottom: "conv11/dw/bn"
#   top: "conv11/dw/relu"
# }
# layer {
#   name: "conv11/sep"
#   type: "Convolution"
#   bottom: "conv11/dw/relu"
#   top: "conv11/sep"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv11/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv11/sep"
#   top: "conv11/sep/bn"
# }
# layer {
#   name: "conv11/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv11/sep/bn"
#   top: "conv11/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv11/sep/relu"
#   type: "ReLU"
#   bottom: "conv11/sep/bn"
#   top: "conv11/sep/relu"
# }
# layer {
#   name: "conv12/dw"
#   type: "Convolution"
#   bottom: "conv11/sep/relu"
#   top: "conv12/dw"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 512
#     stride: 2
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv12/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv12/dw"
#   top: "conv12/dw/bn"
# }
# layer {
#   name: "conv12/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv12/dw/bn"
#   top: "conv12/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv12/dw/relu"
#   type: "ReLU"
#   bottom: "conv12/dw/bn"
#   top: "conv12/dw/relu"
# }
# layer {
#   name: "conv12/sep"
#   type: "Convolution"
#   bottom: "conv12/dw/relu"
#   top: "conv12/sep"
#   convolution_param {
#     num_output: 1024
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv12/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv12/sep"
#   top: "conv12/sep/bn"
# }
# layer {
#   name: "conv12/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv12/sep/bn"
#   top: "conv12/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv12/sep/relu"
#   type: "ReLU"
#   bottom: "conv12/sep/bn"
#   top: "conv12/sep/relu"
# }
# layer {
#   name: "conv13/dw"
#   type: "Convolution"
#   bottom: "conv12/sep/relu"
#   top: "conv13/dw"
#   convolution_param {
#     num_output: 1024
#     bias_term: false
#     pad: 1
#     kernel_size: 3
#     group: 1024
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv13/dw/bn"
#   type: "BatchNorm"
#   bottom: "conv13/dw"
#   top: "conv13/dw/bn"
# }
# layer {
#   name: "conv13/dw/bn/scale"
#   type: "Scale"
#   bottom: "conv13/dw/bn"
#   top: "conv13/dw/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv13/dw/relu"
#   type: "ReLU"
#   bottom: "conv13/dw/bn"
#   top: "conv13/dw/relu"
# }
# layer {
#   name: "conv13/sep"
#   type: "Convolution"
#   bottom: "conv13/dw/relu"
#   top: "conv13/sep"
#   convolution_param {
#     num_output: 1024
#     bias_term: false
#     pad: 0
#     kernel_size: 1
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "msra"
#     }
#     dilation: 1
#   }
# }
# layer {
#   name: "conv13/sep/bn"
#   type: "BatchNorm"
#   bottom: "conv13/sep"
#   top: "conv13/sep/bn"
# }
# layer {
#   name: "conv13/sep/bn/scale"
#   type: "Scale"
#   bottom: "conv13/sep/bn"
#   top: "conv13/sep/bn"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "conv13/sep/relu"
#   type: "ReLU"
#   bottom: "conv13/sep/bn"
#   top: "conv13/sep/relu"
# }
# layer {
#   name: "pool"
#   type: "Pooling"
#   bottom: "conv13/sep/relu"
#   top: "pool"
#   pooling_param {
#     pool: AVE
#     global_pooling: true
#   }
# }
# layer {
#   name: "flatten"
#   type: "Flatten"
#   bottom: "pool"
#   top: "flatten"
#   flatten_param {
#     axis: 1
#   }
# }
# layer {
#   name: "fc"
#   type: "InnerProduct"
#   bottom: "flatten"
#   top: "fc"
#   inner_product_param {
#     num_output: 200
#     bias_term: true
#   }
# }
#
# convert conv: model.0.0 conv0 Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# convert bn: model.0.1 conv0/bn BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.1.0.0 conv1/dw Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
# convert bn: model.1.0.1 conv1/dw/bn BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.1.1.0 conv1/sep Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.1.1.1 conv1/sep/bn BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.2.0.0 conv2/dw Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
# convert bn: model.2.0.1 conv2/dw/bn BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.2.1.0 conv2/sep Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.2.1.1 conv2/sep/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.3.0.0 conv3/dw Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
# convert bn: model.3.0.1 conv3/dw/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.3.1.0 conv3/sep Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.3.1.1 conv3/sep/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.4.0.0 conv4/dw Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128, bias=False)
# convert bn: model.4.0.1 conv4/dw/bn BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.4.1.0 conv4/sep Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.4.1.1 conv4/sep/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.5.0.0 conv5/dw Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
# convert bn: model.5.0.1 conv5/dw/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.5.1.0 conv5/sep Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.5.1.1 conv5/sep/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.6.0.0 conv6/dw Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
# convert bn: model.6.0.1 conv6/dw/bn BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.6.1.0 conv6/sep Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.6.1.1 conv6/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.7.0.0 conv7/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: model.7.0.1 conv7/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.7.1.0 conv7/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.7.1.1 conv7/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.8.0.0 conv8/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: model.8.0.1 conv8/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.8.1.0 conv8/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.8.1.1 conv8/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.9.0.0 conv9/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: model.9.0.1 conv9/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.9.1.0 conv9/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.9.1.1 conv9/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.10.0.0 conv10/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: model.10.0.1 conv10/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.10.1.0 conv10/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.10.1.1 conv10/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.11.0.0 conv11/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
# convert bn: model.11.0.1 conv11/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.11.1.0 conv11/sep Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.11.1.1 conv11/sep/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.12.0.0 conv12/dw Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=512, bias=False)
# convert bn: model.12.0.1 conv12/dw/bn BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.12.1.0 conv12/sep Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.12.1.1 conv12/sep/bn BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.13.0.0 conv13/dw Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
# convert bn: model.13.0.1 conv13/dw/bn BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert conv: model.13.1.0 conv13/sep Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
# convert bn: model.13.1.1 conv13/sep/bn BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# convert fc: model.16 fc Linear(in_features=1024, out_features=200, bias=True)
# ((1, 200), (1, 200))
# (array([-1.45003833e-02,  1.68331005e-02,  1.82758197e-02,  2.45492086e-02,
#         1.95637569e-02,  2.23117582e-02, -1.71928592e-02,  2.74028629e-04,
#         3.00632045e-03,  7.11829215e-03, -5.83919138e-03,  1.29630715e-02,
#         1.46523416e-02, -5.14288992e-03, -1.94739550e-02, -6.00769371e-03,
#        -1.86523385e-02, -3.05854790e-02, -8.31360742e-03,  9.94853675e-04,
#         6.96917623e-03,  2.78616250e-02, -8.19567591e-03, -2.57284194e-02,
#         1.95414610e-02,  2.10766494e-03,  3.00083943e-02,  2.82618701e-02,
#        -2.46931985e-02,  1.32868402e-02, -1.86978281e-02,  2.09360458e-02,
#         1.42678097e-02,  2.67091319e-02,  5.26442751e-03, -3.78591940e-03,
#         2.22931057e-03,  1.91279016e-02,  1.74416713e-02,  1.71479769e-02,
#        -2.43222937e-02,  1.16172954e-02,  2.99934596e-02, -7.87140429e-03,
#        -2.83233784e-02, -2.21189819e-02, -2.08250061e-02,  1.97989605e-02,
#         1.60049908e-02,  8.36250558e-03, -2.27592178e-02,  1.73784010e-02,
#         1.86486356e-02, -2.00792924e-02,  2.47999169e-02, -2.65527517e-02,
#        -2.92029157e-02, -4.70682979e-03, -2.20802948e-02, -2.97339447e-02,
#         1.01592578e-02, -1.40521005e-02, -2.74663344e-02,  1.49681233e-02,
#         1.40948333e-02,  6.49193674e-03,  6.55204430e-03, -2.22237781e-02,
#        -1.34824440e-02,  7.16090947e-03,  2.06088126e-02, -3.08179185e-02,
#         2.44868137e-02,  2.66298316e-02,  5.81204891e-03, -2.51021944e-02,
#        -1.15926191e-03, -2.19195709e-02,  2.76069716e-03,  5.00170514e-03,
#        -4.04737145e-03, -3.05759385e-02,  2.85345502e-02, -2.71308981e-02,
#         3.08668241e-03,  2.21827962e-02, -1.21275596e-02,  1.53155364e-02,
#         1.44451186e-02,  2.43883617e-02, -2.97616124e-02,  2.29602568e-02,
#        -2.27612928e-02,  1.91184022e-02, -7.27523118e-04,  2.18432322e-02,
#        -5.44368476e-03,  1.75179318e-02, -2.95981169e-02, -5.32805920e-03,
#         7.42723793e-03, -9.62704420e-03,  2.94957832e-02, -2.90992111e-02,
#        -7.05252588e-03,  2.91913748e-02,  1.06166191e-02, -1.34439915e-02,
#         2.34583654e-02, -3.03273462e-02, -1.20180808e-02,  5.27406856e-03,
#         1.94250904e-02, -7.61150569e-03, -3.05167139e-02,  5.65258041e-03,
#         1.75966769e-02,  2.04554722e-02,  1.63071454e-02,  9.99600813e-03,
#         2.80598365e-02, -1.35786496e-02, -2.32008658e-02, -3.60608101e-04,
#        -6.18878007e-03,  1.96397752e-02,  1.73045993e-02,  8.67034122e-03,
#        -2.37408206e-02,  1.71214938e-02, -1.80072337e-02, -1.42185837e-02,
#         7.97553360e-03, -2.47718953e-02, -1.21028647e-02, -2.11862959e-02,
#        -1.46475025e-02,  1.10758729e-02,  1.14267431e-02, -4.67059389e-03,
#         6.08293340e-03,  5.11690602e-03,  1.65628791e-02, -1.74128599e-02,
#         1.89379677e-02,  1.78539865e-02,  6.82517514e-03, -1.44535750e-02,
#         1.33949406e-02,  1.84673890e-02, -4.50951234e-03, -1.41590126e-02,
#        -2.31539458e-02,  6.00500405e-03, -5.13140857e-03, -6.06272370e-03,
#         2.45919377e-02,  2.71160677e-02, -1.64903440e-02,  9.64393467e-03,
#         3.05801407e-02,  1.04037747e-02,  2.12577432e-02, -1.90690272e-02,
#        -9.04873013e-06,  1.84277147e-02,  1.17383637e-02,  2.11624242e-02,
#        -1.27198882e-02,  9.09204781e-03, -3.08268405e-02,  3.70496884e-03,
#        -1.79210380e-02,  2.32915990e-02, -1.76789612e-02, -2.40099579e-02,
#         1.51396170e-03,  9.33188573e-03, -6.85419142e-03, -2.67778113e-02,
#        -3.01842391e-02, -1.37254745e-02,  2.63264105e-02,  2.42134556e-03,
#         1.07621662e-02, -2.99122855e-02,  2.24041119e-02, -2.45153457e-02,
#        -1.94819272e-03, -8.53008404e-03, -6.04197383e-04, -2.24615037e-02,
#         8.69894773e-03, -2.42780373e-02,  1.73067972e-02,  8.12898949e-03,
#         1.50810331e-02,  3.05637084e-02, -3.00694257e-02,  3.04707661e-02],
#       dtype=float32), array([-1.45003833e-02,  1.68331005e-02,  1.82758197e-02,  2.45492086e-02,
#         1.95637569e-02,  2.23117582e-02, -1.71928592e-02,  2.74028629e-04,
#         3.00632045e-03,  7.11829215e-03, -5.83919138e-03,  1.29630715e-02,
#         1.46523416e-02, -5.14288992e-03, -1.94739550e-02, -6.00769371e-03,
#        -1.86523385e-02, -3.05854790e-02, -8.31360742e-03,  9.94853675e-04,
#         6.96917623e-03,  2.78616250e-02, -8.19567591e-03, -2.57284194e-02,
#         1.95414610e-02,  2.10766494e-03,  3.00083943e-02,  2.82618701e-02,
#        -2.46931985e-02,  1.32868402e-02, -1.86978281e-02,  2.09360458e-02,
#         1.42678097e-02,  2.67091319e-02,  5.26442751e-03, -3.78591940e-03,
#         2.22931057e-03,  1.91279016e-02,  1.74416713e-02,  1.71479769e-02,
#        -2.43222937e-02,  1.16172954e-02,  2.99934596e-02, -7.87140429e-03,
#        -2.83233784e-02, -2.21189819e-02, -2.08250061e-02,  1.97989605e-02,
#         1.60049908e-02,  8.36250558e-03, -2.27592178e-02,  1.73784010e-02,
#         1.86486356e-02, -2.00792924e-02,  2.47999169e-02, -2.65527517e-02,
#        -2.92029157e-02, -4.70682979e-03, -2.20802948e-02, -2.97339447e-02,
#         1.01592578e-02, -1.40521005e-02, -2.74663344e-02,  1.49681233e-02,
#         1.40948333e-02,  6.49193674e-03,  6.55204430e-03, -2.22237781e-02,
#        -1.34824440e-02,  7.16090947e-03,  2.06088126e-02, -3.08179185e-02,
#         2.44868137e-02,  2.66298316e-02,  5.81204891e-03, -2.51021944e-02,
#        -1.15926191e-03, -2.19195709e-02,  2.76069716e-03,  5.00170514e-03,
#        -4.04737145e-03, -3.05759385e-02,  2.85345502e-02, -2.71308981e-02,
#         3.08668241e-03,  2.21827962e-02, -1.21275596e-02,  1.53155364e-02,
#         1.44451186e-02,  2.43883617e-02, -2.97616124e-02,  2.29602568e-02,
#        -2.27612928e-02,  1.91184022e-02, -7.27523118e-04,  2.18432322e-02,
#        -5.44368476e-03,  1.75179318e-02, -2.95981169e-02, -5.32805920e-03,
#         7.42723793e-03, -9.62704420e-03,  2.94957832e-02, -2.90992111e-02,
#        -7.05252588e-03,  2.91913748e-02,  1.06166191e-02, -1.34439915e-02,
#         2.34583654e-02, -3.03273462e-02, -1.20180808e-02,  5.27406856e-03,
#         1.94250904e-02, -7.61150569e-03, -3.05167139e-02,  5.65258041e-03,
#         1.75966769e-02,  2.04554722e-02,  1.63071454e-02,  9.99600813e-03,
#         2.80598365e-02, -1.35786496e-02, -2.32008658e-02, -3.60608101e-04,
#        -6.18878007e-03,  1.96397752e-02,  1.73045993e-02,  8.67034122e-03,
#        -2.37408206e-02,  1.71214938e-02, -1.80072337e-02, -1.42185837e-02,
#         7.97553360e-03, -2.47718953e-02, -1.21028647e-02, -2.11862959e-02,
#        -1.46475025e-02,  1.10758729e-02,  1.14267431e-02, -4.67059389e-03,
#         6.08293340e-03,  5.11690602e-03,  1.65628791e-02, -1.74128599e-02,
#         1.89379677e-02,  1.78539865e-02,  6.82517514e-03, -1.44535750e-02,
#         1.33949406e-02,  1.84673890e-02, -4.50951234e-03, -1.41590126e-02,
#        -2.31539458e-02,  6.00500405e-03, -5.13140857e-03, -6.06272370e-03,
#         2.45919377e-02,  2.71160677e-02, -1.64903440e-02,  9.64393467e-03,
#         3.05801407e-02,  1.04037747e-02,  2.12577432e-02, -1.90690272e-02,
#        -9.04873013e-06,  1.84277147e-02,  1.17383637e-02,  2.11624242e-02,
#        -1.27198882e-02,  9.09204781e-03, -3.08268405e-02,  3.70496884e-03,
#        -1.79210380e-02,  2.32915990e-02, -1.76789612e-02, -2.40099579e-02,
#         1.51396170e-03,  9.33188573e-03, -6.85419142e-03, -2.67778113e-02,
#        -3.01842391e-02, -1.37254745e-02,  2.63264105e-02,  2.42134556e-03,
#         1.07621662e-02, -2.99122855e-02,  2.24041119e-02, -2.45153457e-02,
#        -1.94819272e-03, -8.53008404e-03, -6.04197383e-04, -2.24615037e-02,
#         8.69894773e-03, -2.42780373e-02,  1.73067972e-02,  8.12898949e-03,
#         1.50810331e-02,  3.05637084e-02, -3.00694257e-02,  3.04707661e-02],
#       dtype=float32))
# mean diff = 0.000000
# max diff = 0.000000

# %%
alpha=0.25
# deploy = "/media/allen/mass/deep-learning-works/caffe_models/MobileNetV1_{}.prototxt".format(alpha)
# caffemodel = "/media/allen/mass/deep-learning-works/caffe_models/MobileNetV1_{}.caffemodel".format(alpha)
deploy = "/media/allen/mass/deep-learning-works/caffe_models/GAE.prototxt"
caffemodel = "/media/allen/mass/deep-learning-works/caffe_models/GAE.caffemodel"
from model.c2tf import Network
network = Network(deploy, caffemodel, name='GAE')#'MobileNetV1_{}'.format(alpha))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0923 13:31:49.615722 140015460574976 deprecation_wrapper.py:119] From /media/allen/mass/deep-learning-works/model/c2tf.py:35: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.

# %%
network.build()
# Out:
# W0923 13:31:53.885008 140015460574976 deprecation_wrapper.py:119] From /media/allen/mass/deep-learning-works/model/c2tf.py:112: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0923 13:31:53.890152 140015460574976 deprecation_wrapper.py:119] From /media/allen/mass/deep-learning-works/model/c2tf.py:115: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0923 13:31:53.894754 140015460574976 deprecation.py:506] From /home/allen/.pyenv/versions/tf/local/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0923 13:31:53.947460 140015460574976 deprecation_wrapper.py:119] From /media/allen/mass/deep-learning-works/model/c2tf.py:142: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# data
# conv0
# conv0/bn
# conv0/bn/scale
# Merge into BN
# conv0/relu
# conv1/dw
# conv1/dw/bn
# conv1/dw/bn/scale
# Merge into BN
# conv1/dw/relu
# conv1/sep
# conv1/sep/bn
# conv1/sep/bn/scale
# Merge into BN
# conv1/sep/relu
# conv2/dw
# conv2/dw/bn
# conv2/dw/bn/scale
# Merge into BN
# conv2/dw/relu
# conv2/sep
# conv2/sep/bn
# conv2/sep/bn/scale
# Merge into BN
# conv2/sep/relu
# conv3/dw
# conv3/dw/bn
# conv3/dw/bn/scale
# Merge into BN
# conv3/dw/relu
# conv3/sep
# conv3/sep/bn
# conv3/sep/bn/scale
# Merge into BN
# conv3/sep/relu
# conv4/dw
# conv4/dw/bn
# conv4/dw/bn/scale
# Merge into BN
# conv4/dw/relu
# conv4/sep
# conv4/sep/bn
# conv4/sep/bn/scale
# Merge into BN
# conv4/sep/relu
# conv5/dw
# conv5/dw/bn
# conv5/dw/bn/scale
# Merge into BN
# conv5/dw/relu
# conv5/sep
# conv5/sep/bn
# conv5/sep/bn/scale
# Merge into BN
# conv5/sep/relu
# conv6/dw
# conv6/dw/bn
# conv6/dw/bn/scale
# Merge into BN
# conv6/dw/relu
# conv6/sep
# conv6/sep/bn
# conv6/sep/bn/scale
# Merge into BN
# conv6/sep/relu
# conv7/dw
# conv7/dw/bn
# conv7/dw/bn/scale
# Merge into BN
# conv7/dw/relu
# conv7/sep
# conv7/sep/bn
# conv7/sep/bn/scale
# Merge into BN
# conv7/sep/relu
# conv8/dw
# conv8/dw/bn
# conv8/dw/bn/scale
# Merge into BN
# conv8/dw/relu
# conv8/sep
# conv8/sep/bn
# conv8/sep/bn/scale
# Merge into BN
# conv8/sep/relu
# conv9/dw
# conv9/dw/bn
# conv9/dw/bn/scale
# Merge into BN
# conv9/dw/relu
# conv9/sep
# conv9/sep/bn
# conv9/sep/bn/scale
# Merge into BN
# conv9/sep/relu
# conv10/dw
# conv10/dw/bn
# conv10/dw/bn/scale
# Merge into BN
# conv10/dw/relu
# conv10/sep
# conv10/sep/bn
# conv10/sep/bn/scale
# Merge into BN
# conv10/sep/relu
# conv11/dw
# conv11/dw/bn
# conv11/dw/bn/scale
# Merge into BN
# conv11/dw/relu
# conv11/sep
# conv11/sep/bn
# conv11/sep/bn/scale
# Merge into BN
# conv11/sep/relu
# conv12/dw
# conv12/dw/bn
# conv12/dw/bn/scale
# Merge into BN
# conv12/dw/relu
# conv12/sep
# conv12/sep/bn
# conv12/sep/bn/scale
# Merge into BN
# conv12/sep/relu
# conv13/dw
# conv13/dw/bn
# conv13/dw/bn/scale
# Merge into BN
# conv13/dw/relu
# conv13/sep
# conv13/sep/bn
# conv13/sep/bn/scale
# Merge into BN
# conv13/sep/relu
# reshape
# gender
# sigmoid
# age
# emotion

# %%
network.show_graph()
# Out:
# GAE/data                                      Placeholder
# GAE/block1/conv1/conv0_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv1/conv0_conv/Initializer/random_uniform/min Const
# GAE/block1/conv1/conv0_conv/Initializer/random_uniform/max Const
# GAE/block1/conv1/conv0_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv1/conv0_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv1/conv0_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv1/conv0_conv/Initializer/random_uniform Add
# GAE/block1/conv1/conv0_conv                   VariableV2
# GAE/block1/conv1/conv0_conv/Assign            Assign
# GAE/block1/conv1/conv0_conv/read              Identity
# GAE/block1/conv1/conv0_pad/paddings           Const
# GAE/block1/conv1/conv0_pad                    Pad
# GAE/block1/conv1/conv0                        Conv2D
# GAE/block1/conv1/output                       Identity
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv1/BatchNorm/conv0/bn_mean      VariableV2
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/Assign Assign
# GAE/block1/conv1/BatchNorm/conv0/bn_mean/read Identity
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Initializer/random_uniform Add
# GAE/block1/conv1/BatchNorm/conv0/bn_var       VariableV2
# GAE/block1/conv1/BatchNorm/conv0/bn_var/Assign Assign
# GAE/block1/conv1/BatchNorm/conv0/bn_var/read  Identity
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv1/BatchNorm/conv0/bn_scale     VariableV2
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/Assign Assign
# GAE/block1/conv1/BatchNorm/conv0/bn_scale/read Identity
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv1/BatchNorm/conv0/bn_offset    VariableV2
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/Assign Assign
# GAE/block1/conv1/BatchNorm/conv0/bn_offset/read Identity
# GAE/block1/conv1/BatchNorm/conv0/bn           FusedBatchNorm
# GAE/block1/conv1/BatchNorm/output             Identity
# GAE/block1/conv1/ReLU/conv0/relu              Relu
# GAE/block1/conv1/ReLU/output                  Identity
# GAE/block1/conv2/conv1/dw_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv2/conv1/dw_conv/Initializer/random_uniform/min Const
# GAE/block1/conv2/conv1/dw_conv/Initializer/random_uniform/max Const
# GAE/block1/conv2/conv1/dw_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv2/conv1/dw_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv2/conv1/dw_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv2/conv1/dw_conv/Initializer/random_uniform Add
# GAE/block1/conv2/conv1/dw_conv                VariableV2
# GAE/block1/conv2/conv1/dw_conv/Assign         Assign
# GAE/block1/conv2/conv1/dw_conv/read           Identity
# GAE/block1/conv2/conv1/dw_pad/paddings        Const
# GAE/block1/conv2/conv1/dw_pad                 Pad
# GAE/block1/conv2/conv1/dw/Shape               Const
# GAE/block1/conv2/conv1/dw/dilation_rate       Const
# GAE/block1/conv2/conv1/dw                     DepthwiseConv2dNative
# GAE/block1/conv2/output                       Identity
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean   VariableV2
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/Assign Assign
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_mean/read Identity
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Initializer/random_uniform Add
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var    VariableV2
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/Assign Assign
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_var/read Identity
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale  VariableV2
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/Assign Assign
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_scale/read Identity
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset VariableV2
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/Assign Assign
# GAE/block1/conv2/BatchNorm/conv1/dw/bn_offset/read Identity
# GAE/block1/conv2/BatchNorm/conv1/dw/bn        FusedBatchNorm
# GAE/block1/conv2/BatchNorm/output             Identity
# GAE/block1/conv2/ReLU/conv1/dw/relu           Relu
# GAE/block1/conv2/ReLU/output                  Identity
# GAE/block1/conv3/conv1/sep_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv3/conv1/sep_conv/Initializer/random_uniform/min Const
# GAE/block1/conv3/conv1/sep_conv/Initializer/random_uniform/max Const
# GAE/block1/conv3/conv1/sep_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv3/conv1/sep_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv3/conv1/sep_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv3/conv1/sep_conv/Initializer/random_uniform Add
# GAE/block1/conv3/conv1/sep_conv               VariableV2
# GAE/block1/conv3/conv1/sep_conv/Assign        Assign
# GAE/block1/conv3/conv1/sep_conv/read          Identity
# GAE/block1/conv3/conv1/sep                    Conv2D
# GAE/block1/conv3/output                       Identity
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean  VariableV2
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/Assign Assign
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_mean/read Identity
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Initializer/random_uniform Add
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var   VariableV2
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/Assign Assign
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_var/read Identity
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale VariableV2
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/Assign Assign
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_scale/read Identity
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset VariableV2
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/Assign Assign
# GAE/block1/conv3/BatchNorm/conv1/sep/bn_offset/read Identity
# GAE/block1/conv3/BatchNorm/conv1/sep/bn       FusedBatchNorm
# GAE/block1/conv3/BatchNorm/output             Identity
# GAE/block1/conv3/ReLU/conv1/sep/relu          Relu
# GAE/block1/conv3/ReLU/output                  Identity
# GAE/block1/conv4/conv2/dw_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv4/conv2/dw_conv/Initializer/random_uniform/min Const
# GAE/block1/conv4/conv2/dw_conv/Initializer/random_uniform/max Const
# GAE/block1/conv4/conv2/dw_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv4/conv2/dw_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv4/conv2/dw_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv4/conv2/dw_conv/Initializer/random_uniform Add
# GAE/block1/conv4/conv2/dw_conv                VariableV2
# GAE/block1/conv4/conv2/dw_conv/Assign         Assign
# GAE/block1/conv4/conv2/dw_conv/read           Identity
# GAE/block1/conv4/conv2/dw_pad/paddings        Const
# GAE/block1/conv4/conv2/dw_pad                 Pad
# GAE/block1/conv4/conv2/dw/Shape               Const
# GAE/block1/conv4/conv2/dw/dilation_rate       Const
# GAE/block1/conv4/conv2/dw                     DepthwiseConv2dNative
# GAE/block1/conv4/output                       Identity
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean   VariableV2
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/Assign Assign
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_mean/read Identity
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Initializer/random_uniform Add
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var    VariableV2
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/Assign Assign
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_var/read Identity
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale  VariableV2
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/Assign Assign
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_scale/read Identity
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset VariableV2
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/Assign Assign
# GAE/block1/conv4/BatchNorm/conv2/dw/bn_offset/read Identity
# GAE/block1/conv4/BatchNorm/conv2/dw/bn        FusedBatchNorm
# GAE/block1/conv4/BatchNorm/output             Identity
# GAE/block1/conv4/ReLU/conv2/dw/relu           Relu
# GAE/block1/conv4/ReLU/output                  Identity
# GAE/block1/conv5/conv2/sep_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv5/conv2/sep_conv/Initializer/random_uniform/min Const
# GAE/block1/conv5/conv2/sep_conv/Initializer/random_uniform/max Const
# GAE/block1/conv5/conv2/sep_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv5/conv2/sep_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv5/conv2/sep_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv5/conv2/sep_conv/Initializer/random_uniform Add
# GAE/block1/conv5/conv2/sep_conv               VariableV2
# GAE/block1/conv5/conv2/sep_conv/Assign        Assign
# GAE/block1/conv5/conv2/sep_conv/read          Identity
# GAE/block1/conv5/conv2/sep                    Conv2D
# GAE/block1/conv5/output                       Identity
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean  VariableV2
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/Assign Assign
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_mean/read Identity
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Initializer/random_uniform Add
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var   VariableV2
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/Assign Assign
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_var/read Identity
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale VariableV2
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/Assign Assign
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_scale/read Identity
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset VariableV2
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/Assign Assign
# GAE/block1/conv5/BatchNorm/conv2/sep/bn_offset/read Identity
# GAE/block1/conv5/BatchNorm/conv2/sep/bn       FusedBatchNorm
# GAE/block1/conv5/BatchNorm/output             Identity
# GAE/block1/conv5/ReLU/conv2/sep/relu          Relu
# GAE/block1/conv5/ReLU/output                  Identity
# GAE/block1/conv6/conv3/dw_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv6/conv3/dw_conv/Initializer/random_uniform/min Const
# GAE/block1/conv6/conv3/dw_conv/Initializer/random_uniform/max Const
# GAE/block1/conv6/conv3/dw_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv6/conv3/dw_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv6/conv3/dw_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv6/conv3/dw_conv/Initializer/random_uniform Add
# GAE/block1/conv6/conv3/dw_conv                VariableV2
# GAE/block1/conv6/conv3/dw_conv/Assign         Assign
# GAE/block1/conv6/conv3/dw_conv/read           Identity
# GAE/block1/conv6/conv3/dw_pad/paddings        Const
# GAE/block1/conv6/conv3/dw_pad                 Pad
# GAE/block1/conv6/conv3/dw/Shape               Const
# GAE/block1/conv6/conv3/dw/dilation_rate       Const
# GAE/block1/conv6/conv3/dw                     DepthwiseConv2dNative
# GAE/block1/conv6/output                       Identity
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean   VariableV2
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/Assign Assign
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_mean/read Identity
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Initializer/random_uniform Add
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var    VariableV2
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/Assign Assign
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_var/read Identity
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale  VariableV2
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/Assign Assign
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_scale/read Identity
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset VariableV2
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/Assign Assign
# GAE/block1/conv6/BatchNorm/conv3/dw/bn_offset/read Identity
# GAE/block1/conv6/BatchNorm/conv3/dw/bn        FusedBatchNorm
# GAE/block1/conv6/BatchNorm/output             Identity
# GAE/block1/conv6/ReLU/conv3/dw/relu           Relu
# GAE/block1/conv6/ReLU/output                  Identity
# GAE/block1/conv7/conv3/sep_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv7/conv3/sep_conv/Initializer/random_uniform/min Const
# GAE/block1/conv7/conv3/sep_conv/Initializer/random_uniform/max Const
# GAE/block1/conv7/conv3/sep_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv7/conv3/sep_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv7/conv3/sep_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv7/conv3/sep_conv/Initializer/random_uniform Add
# GAE/block1/conv7/conv3/sep_conv               VariableV2
# GAE/block1/conv7/conv3/sep_conv/Assign        Assign
# GAE/block1/conv7/conv3/sep_conv/read          Identity
# GAE/block1/conv7/conv3/sep                    Conv2D
# GAE/block1/conv7/output                       Identity
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean  VariableV2
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/Assign Assign
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_mean/read Identity
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Initializer/random_uniform Add
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var   VariableV2
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/Assign Assign
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_var/read Identity
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale VariableV2
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/Assign Assign
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_scale/read Identity
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset VariableV2
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/Assign Assign
# GAE/block1/conv7/BatchNorm/conv3/sep/bn_offset/read Identity
# GAE/block1/conv7/BatchNorm/conv3/sep/bn       FusedBatchNorm
# GAE/block1/conv7/BatchNorm/output             Identity
# GAE/block1/conv7/ReLU/conv3/sep/relu          Relu
# GAE/block1/conv7/ReLU/output                  Identity
# GAE/block1/conv8/conv4/dw_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv8/conv4/dw_conv/Initializer/random_uniform/min Const
# GAE/block1/conv8/conv4/dw_conv/Initializer/random_uniform/max Const
# GAE/block1/conv8/conv4/dw_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv8/conv4/dw_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv8/conv4/dw_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv8/conv4/dw_conv/Initializer/random_uniform Add
# GAE/block1/conv8/conv4/dw_conv                VariableV2
# GAE/block1/conv8/conv4/dw_conv/Assign         Assign
# GAE/block1/conv8/conv4/dw_conv/read           Identity
# GAE/block1/conv8/conv4/dw_pad/paddings        Const
# GAE/block1/conv8/conv4/dw_pad                 Pad
# GAE/block1/conv8/conv4/dw/Shape               Const
# GAE/block1/conv8/conv4/dw/dilation_rate       Const
# GAE/block1/conv8/conv4/dw                     DepthwiseConv2dNative
# GAE/block1/conv8/output                       Identity
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean   VariableV2
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/Assign Assign
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_mean/read Identity
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Initializer/random_uniform Add
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var    VariableV2
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/Assign Assign
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_var/read Identity
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale  VariableV2
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/Assign Assign
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_scale/read Identity
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset VariableV2
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/Assign Assign
# GAE/block1/conv8/BatchNorm/conv4/dw/bn_offset/read Identity
# GAE/block1/conv8/BatchNorm/conv4/dw/bn        FusedBatchNorm
# GAE/block1/conv8/BatchNorm/output             Identity
# GAE/block1/conv8/ReLU/conv4/dw/relu           Relu
# GAE/block1/conv8/ReLU/output                  Identity
# GAE/block1/conv9/conv4/sep_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv9/conv4/sep_conv/Initializer/random_uniform/min Const
# GAE/block1/conv9/conv4/sep_conv/Initializer/random_uniform/max Const
# GAE/block1/conv9/conv4/sep_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv9/conv4/sep_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv9/conv4/sep_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv9/conv4/sep_conv/Initializer/random_uniform Add
# GAE/block1/conv9/conv4/sep_conv               VariableV2
# GAE/block1/conv9/conv4/sep_conv/Assign        Assign
# GAE/block1/conv9/conv4/sep_conv/read          Identity
# GAE/block1/conv9/conv4/sep                    Conv2D
# GAE/block1/conv9/output                       Identity
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean  VariableV2
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/Assign Assign
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_mean/read Identity
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Initializer/random_uniform Add
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var   VariableV2
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/Assign Assign
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_var/read Identity
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale VariableV2
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/Assign Assign
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_scale/read Identity
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset VariableV2
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/Assign Assign
# GAE/block1/conv9/BatchNorm/conv4/sep/bn_offset/read Identity
# GAE/block1/conv9/BatchNorm/conv4/sep/bn       FusedBatchNorm
# GAE/block1/conv9/BatchNorm/output             Identity
# GAE/block1/conv9/ReLU/conv4/sep/relu          Relu
# GAE/block1/conv9/ReLU/output                  Identity
# GAE/block1/conv10/conv5/dw_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv10/conv5/dw_conv/Initializer/random_uniform/min Const
# GAE/block1/conv10/conv5/dw_conv/Initializer/random_uniform/max Const
# GAE/block1/conv10/conv5/dw_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv10/conv5/dw_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv10/conv5/dw_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv10/conv5/dw_conv/Initializer/random_uniform Add
# GAE/block1/conv10/conv5/dw_conv               VariableV2
# GAE/block1/conv10/conv5/dw_conv/Assign        Assign
# GAE/block1/conv10/conv5/dw_conv/read          Identity
# GAE/block1/conv10/conv5/dw_pad/paddings       Const
# GAE/block1/conv10/conv5/dw_pad                Pad
# GAE/block1/conv10/conv5/dw/Shape              Const
# GAE/block1/conv10/conv5/dw/dilation_rate      Const
# GAE/block1/conv10/conv5/dw                    DepthwiseConv2dNative
# GAE/block1/conv10/output                      Identity
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean  VariableV2
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/Assign Assign
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_mean/read Identity
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Initializer/random_uniform Add
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var   VariableV2
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/Assign Assign
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_var/read Identity
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv10/BatchNorm/conv5/dw/bn_scale VariableV2
# ...
# GAE/block1/conv25/BatchNorm/conv12/sep/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv25/BatchNorm/conv12/sep/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv25/BatchNorm/conv12/sep/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv25/BatchNorm/conv12/sep/bn_offset VariableV2
# GAE/block1/conv25/BatchNorm/conv12/sep/bn_offset/Assign Assign
# GAE/block1/conv25/BatchNorm/conv12/sep/bn_offset/read Identity
# GAE/block1/conv25/BatchNorm/conv12/sep/bn     FusedBatchNorm
# GAE/block1/conv25/BatchNorm/output            Identity
# GAE/block1/conv25/ReLU/conv12/sep/relu        Relu
# GAE/block1/conv25/ReLU/output                 Identity
# GAE/block1/conv26/conv13/dw_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv26/conv13/dw_conv/Initializer/random_uniform/min Const
# GAE/block1/conv26/conv13/dw_conv/Initializer/random_uniform/max Const
# GAE/block1/conv26/conv13/dw_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv26/conv13/dw_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv26/conv13/dw_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv26/conv13/dw_conv/Initializer/random_uniform Add
# GAE/block1/conv26/conv13/dw_conv              VariableV2
# GAE/block1/conv26/conv13/dw_conv/Assign       Assign
# GAE/block1/conv26/conv13/dw_conv/read         Identity
# GAE/block1/conv26/conv13/dw_pad/paddings      Const
# GAE/block1/conv26/conv13/dw_pad               Pad
# GAE/block1/conv26/conv13/dw/Shape             Const
# GAE/block1/conv26/conv13/dw/dilation_rate     Const
# GAE/block1/conv26/conv13/dw                   DepthwiseConv2dNative
# GAE/block1/conv26/output                      Identity
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean VariableV2
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/Assign Assign
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_mean/read Identity
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Initializer/random_uniform Add
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var  VariableV2
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/Assign Assign
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_var/read Identity
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale VariableV2
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/Assign Assign
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_scale/read Identity
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset VariableV2
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/Assign Assign
# GAE/block1/conv26/BatchNorm/conv13/dw/bn_offset/read Identity
# GAE/block1/conv26/BatchNorm/conv13/dw/bn      FusedBatchNorm
# GAE/block1/conv26/BatchNorm/output            Identity
# GAE/block1/conv26/ReLU/conv13/dw/relu         Relu
# GAE/block1/conv26/ReLU/output                 Identity
# GAE/block1/conv27/conv13/sep_conv/Initializer/random_uniform/shape Const
# GAE/block1/conv27/conv13/sep_conv/Initializer/random_uniform/min Const
# GAE/block1/conv27/conv13/sep_conv/Initializer/random_uniform/max Const
# GAE/block1/conv27/conv13/sep_conv/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv27/conv13/sep_conv/Initializer/random_uniform/sub Sub
# GAE/block1/conv27/conv13/sep_conv/Initializer/random_uniform/mul Mul
# GAE/block1/conv27/conv13/sep_conv/Initializer/random_uniform Add
# GAE/block1/conv27/conv13/sep_conv             VariableV2
# GAE/block1/conv27/conv13/sep_conv/Assign      Assign
# GAE/block1/conv27/conv13/sep_conv/read        Identity
# GAE/block1/conv27/conv13/sep                  Conv2D
# GAE/block1/conv27/output                      Identity
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Initializer/random_uniform/shape Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Initializer/random_uniform/min Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Initializer/random_uniform/max Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Initializer/random_uniform/sub Sub
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Initializer/random_uniform/mul Mul
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Initializer/random_uniform Add
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean VariableV2
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/Assign Assign
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_mean/read Identity
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Initializer/random_uniform/shape Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Initializer/random_uniform/min Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Initializer/random_uniform/max Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Initializer/random_uniform/sub Sub
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Initializer/random_uniform/mul Mul
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Initializer/random_uniform Add
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var VariableV2
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/Assign Assign
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_var/read Identity
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Initializer/random_uniform/shape Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Initializer/random_uniform/min Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Initializer/random_uniform/max Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Initializer/random_uniform/sub Sub
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Initializer/random_uniform/mul Mul
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Initializer/random_uniform Add
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale VariableV2
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/Assign Assign
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_scale/read Identity
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Initializer/random_uniform/shape Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Initializer/random_uniform/min Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Initializer/random_uniform/max Const
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Initializer/random_uniform/sub Sub
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Initializer/random_uniform/mul Mul
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Initializer/random_uniform Add
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset VariableV2
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/Assign Assign
# GAE/block1/conv27/BatchNorm/conv13/sep/bn_offset/read Identity
# GAE/block1/conv27/BatchNorm/conv13/sep/bn     FusedBatchNorm
# GAE/block1/conv27/BatchNorm/output            Identity
# GAE/block1/conv27/ReLU/conv13/sep/relu        Relu
# GAE/block1/conv27/ReLU/output                 Identity
# GAE/block1/conv27/Flatten/reshape/shape       Const
# GAE/block1/conv27/Flatten/reshape             Reshape
# GAE/block1/conv27/Flatten/output              Identity
# GAE/fc1/gender_fc_w/Initializer/random_uniform/shape Const
# GAE/fc1/gender_fc_w/Initializer/random_uniform/min Const
# GAE/fc1/gender_fc_w/Initializer/random_uniform/max Const
# GAE/fc1/gender_fc_w/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/fc1/gender_fc_w/Initializer/random_uniform/sub Sub
# GAE/fc1/gender_fc_w/Initializer/random_uniform/mul Mul
# GAE/fc1/gender_fc_w/Initializer/random_uniform Add
# GAE/fc1/gender_fc_w                           VariableV2
# GAE/fc1/gender_fc_w/Assign                    Assign
# GAE/fc1/gender_fc_w/read                      Identity
# GAE/fc1/gender_fc_b/Initializer/random_uniform/shape Const
# GAE/fc1/gender_fc_b/Initializer/random_uniform/min Const
# GAE/fc1/gender_fc_b/Initializer/random_uniform/max Const
# GAE/fc1/gender_fc_b/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/fc1/gender_fc_b/Initializer/random_uniform/sub Sub
# GAE/fc1/gender_fc_b/Initializer/random_uniform/mul Mul
# GAE/fc1/gender_fc_b/Initializer/random_uniform Add
# GAE/fc1/gender_fc_b                           VariableV2
# GAE/fc1/gender_fc_b/Assign                    Assign
# GAE/fc1/gender_fc_b/read                      Identity
# GAE/fc1/gender/MatMul                         MatMul
# GAE/fc1/gender                                BiasAdd
# GAE/fc1/output                                Identity
# GAE/fc1/Sigmoid/sigmoid                       Sigmoid
# GAE/fc1/Sigmoid/output                        Identity
# GAE/fc2/age_fc_w/Initializer/random_uniform/shape Const
# GAE/fc2/age_fc_w/Initializer/random_uniform/min Const
# GAE/fc2/age_fc_w/Initializer/random_uniform/max Const
# GAE/fc2/age_fc_w/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/fc2/age_fc_w/Initializer/random_uniform/sub Sub
# GAE/fc2/age_fc_w/Initializer/random_uniform/mul Mul
# GAE/fc2/age_fc_w/Initializer/random_uniform   Add
# GAE/fc2/age_fc_w                              VariableV2
# GAE/fc2/age_fc_w/Assign                       Assign
# GAE/fc2/age_fc_w/read                         Identity
# GAE/fc2/age_fc_b/Initializer/random_uniform/shape Const
# GAE/fc2/age_fc_b/Initializer/random_uniform/min Const
# GAE/fc2/age_fc_b/Initializer/random_uniform/max Const
# GAE/fc2/age_fc_b/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/fc2/age_fc_b/Initializer/random_uniform/sub Sub
# GAE/fc2/age_fc_b/Initializer/random_uniform/mul Mul
# GAE/fc2/age_fc_b/Initializer/random_uniform   Add
# GAE/fc2/age_fc_b                              VariableV2
# GAE/fc2/age_fc_b/Assign                       Assign
# GAE/fc2/age_fc_b/read                         Identity
# GAE/fc2/age/MatMul                            MatMul
# GAE/fc2/age                                   BiasAdd
# GAE/fc2/output                                Identity
# GAE/fc3/emotion_fc_w/Initializer/random_uniform/shape Const
# GAE/fc3/emotion_fc_w/Initializer/random_uniform/min Const
# GAE/fc3/emotion_fc_w/Initializer/random_uniform/max Const
# GAE/fc3/emotion_fc_w/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/fc3/emotion_fc_w/Initializer/random_uniform/sub Sub
# GAE/fc3/emotion_fc_w/Initializer/random_uniform/mul Mul
# GAE/fc3/emotion_fc_w/Initializer/random_uniform Add
# GAE/fc3/emotion_fc_w                          VariableV2
# GAE/fc3/emotion_fc_w/Assign                   Assign
# GAE/fc3/emotion_fc_w/read                     Identity
# GAE/fc3/emotion_fc_b/Initializer/random_uniform/shape Const
# GAE/fc3/emotion_fc_b/Initializer/random_uniform/min Const
# GAE/fc3/emotion_fc_b/Initializer/random_uniform/max Const
# GAE/fc3/emotion_fc_b/Initializer/random_uniform/RandomUniform RandomUniform
# GAE/fc3/emotion_fc_b/Initializer/random_uniform/sub Sub
# GAE/fc3/emotion_fc_b/Initializer/random_uniform/mul Mul
# GAE/fc3/emotion_fc_b/Initializer/random_uniform Add
# GAE/fc3/emotion_fc_b                          VariableV2
# GAE/fc3/emotion_fc_b/Assign                   Assign
# GAE/fc3/emotion_fc_b/read                     Identity
# GAE/fc3/emotion/MatMul                        MatMul
# GAE/fc3/emotion                               BiasAdd
# GAE/fc3/output                                Identity

# %%
network.allocate_weights()

# %%
train_writer = tf.summary.FileWriter(".")
train_writer.add_graph(network.graph)

# %%
# model_name = 'MobileNetV1_{}'.format(alpha)
model_name = 'GAE'
output_name = "GAE/fc1/Sigmoid/output ,GAE/fc2/output ,GAE/fc3/output "
# output_name = "MobileNetV1_{}/fc1/output".format(alpha)

saver = tf.compat.v1.train.Saver()
saver.save(network.sess, "./output/{}.ckpt".format(model_name))
# Out:
# './output/GAE.ckpt'

# %%
with tf.io.gfile.GFile('./output/{}.pb'.format(model_name), 'wb') as f:
    f.write(network.sess.graph_def.SerializeToString())

# %%
from tensorflow.python.tools.freeze_graph import freeze_graph
d = freeze_graph("./output/{}.pb".format(model_name), "",
             True, "./output/{}.ckpt".format(model_name),
             output_name, 'save/restore_all',
             'save/Const:0', "./output/frozen_{}.pb".format(model_name),
             True, '')
# Out:
# W0923 13:33:41.515788 140015460574976 deprecation.py:323] From /home/allen/.pyenv/versions/tf/local/lib/python2.7/site-packages/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0923 13:33:42.312180 140015460574976 deprecation.py:323] From /home/allen/.pyenv/versions/tf/local/lib/python2.7/site-packages/tensorflow/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0923 13:33:42.313680 140015460574976 deprecation.py:323] From /home/allen/.pyenv/versions/tf/local/lib/python2.7/site-packages/tensorflow/python/framework/graph_util_impl.py:270: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`

# %%
network.caffe_layer_list['356'].eltwise_param.operation == 1
# Out:
# True

# %%
network.caffe_layer_list['max_pool2'].pooling_param
params = network.caffe_layer_list['max_pool2'].pooling_param
p_h = params.pad_h
p_w = params.pad_w
k_size = params.kernel_size
s = params.stride           
op = params.pool

# %%
network.caffe_graph
# Out:
# layer {
#   name: "0"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 1
#       dim: 3
#       dim: 112
#       dim: 112
#     }
#   }
# }
# layer {
#   name: "334"
#   type: "Convolution"
#   bottom: "data"
#   top: "334"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     group: 1
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 2
#     stride_w: 2
#     dilation: 1
#   }
# }
# layer {
#   name: "335_bn"
#   type: "BatchNorm"
#   bottom: "334"
#   top: "335"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "335_bn_scale"
#   type: "Scale"
#   bottom: "335"
#   top: "335"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "336_prelu"
#   type: "PReLU"
#   bottom: "335"
#   top: "336"
# }
# layer {
#   name: "337"
#   type: "Convolution"
#   bottom: "336"
#   top: "337"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     group: 64
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "338_bn"
#   type: "BatchNorm"
#   bottom: "337"
#   top: "338"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "338_bn_scale"
#   type: "Scale"
#   bottom: "338"
#   top: "338"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "339_prelu"
#   type: "PReLU"
#   bottom: "338"
#   top: "339"
# }
# layer {
#   name: "340"
#   type: "Convolution"
#   bottom: "339"
#   top: "340"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "341_bn"
#   type: "BatchNorm"
#   bottom: "340"
#   top: "341"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "341_bn_scale"
#   type: "Scale"
#   bottom: "341"
#   top: "341"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "342_prelu"
#   type: "PReLU"
#   bottom: "341"
#   top: "342"
# }
# layer {
#   name: "343"
#   type: "Convolution"
#   bottom: "342"
#   top: "343"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 128
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 2
#     stride_w: 2
#     dilation: 1
#   }
# }
# layer {
#   name: "344_bn"
#   type: "BatchNorm"
#   bottom: "343"
#   top: "344"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "344_bn_scale"
#   type: "Scale"
#   bottom: "344"
#   top: "344"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "345_prelu"
#   type: "PReLU"
#   bottom: "344"
#   top: "345"
# }
# layer {
#   name: "346"
#   type: "Convolution"
#   bottom: "345"
#   top: "346"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "347_bn"
#   type: "BatchNorm"
#   bottom: "346"
#   top: "347"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "347_bn_scale"
#   type: "Scale"
#   bottom: "347"
#   top: "347"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "348"
#   type: "Convolution"
#   bottom: "347"
#   top: "348"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "349_bn"
#   type: "BatchNorm"
#   bottom: "348"
#   top: "349"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "349_bn_scale"
#   type: "Scale"
#   bottom: "349"
#   top: "349"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "350_prelu"
#   type: "PReLU"
#   bottom: "349"
#   top: "350"
# }
# layer {
#   name: "351"
#   type: "Convolution"
#   bottom: "350"
#   top: "351"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 128
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "352_bn"
#   type: "BatchNorm"
#   bottom: "351"
#   top: "352"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "352_bn_scale"
#   type: "Scale"
#   bottom: "352"
#   top: "352"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "353_prelu"
#   type: "PReLU"
#   bottom: "352"
#   top: "353"
# }
# layer {
#   name: "354"
#   type: "Convolution"
#   bottom: "353"
#   top: "354"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "355_bn"
#   type: "BatchNorm"
#   bottom: "354"
#   top: "355"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "355_bn_scale"
#   type: "Scale"
#   bottom: "355"
#   top: "355"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "356"
#   type: "Eltwise"
#   bottom: "347"
#   bottom: "355"
#   top: "356"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "357"
#   type: "Convolution"
#   bottom: "356"
#   top: "357"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "358_bn"
#   type: "BatchNorm"
#   bottom: "357"
#   top: "358"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "358_bn_scale"
#   type: "Scale"
#   bottom: "358"
#   top: "358"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "359_prelu"
#   type: "PReLU"
#   bottom: "358"
#   top: "359"
# }
# layer {
#   name: "360"
#   type: "Convolution"
#   bottom: "359"
#   top: "360"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 128
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "361_bn"
#   type: "BatchNorm"
#   bottom: "360"
#   top: "361"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "361_bn_scale"
#   type: "Scale"
#   bottom: "361"
#   top: "361"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "362_prelu"
#   type: "PReLU"
#   bottom: "361"
#   top: "362"
# }
# layer {
#   name: "363"
#   type: "Convolution"
#   bottom: "362"
#   top: "363"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "364_bn"
#   type: "BatchNorm"
#   bottom: "363"
#   top: "364"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "364_bn_scale"
#   type: "Scale"
#   bottom: "364"
#   top: "364"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "365"
#   type: "Eltwise"
#   bottom: "356"
#   bottom: "364"
#   top: "365"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "366"
#   type: "Convolution"
#   bottom: "365"
#   top: "366"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "367_bn"
#   type: "BatchNorm"
#   bottom: "366"
#   top: "367"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "367_bn_scale"
#   type: "Scale"
#   bottom: "367"
#   top: "367"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "368_prelu"
#   type: "PReLU"
#   bottom: "367"
#   top: "368"
# }
# layer {
#   name: "369"
#   type: "Convolution"
#   bottom: "368"
#   top: "369"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 128
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "370_bn"
#   type: "BatchNorm"
#   bottom: "369"
#   top: "370"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "370_bn_scale"
#   type: "Scale"
#   bottom: "370"
#   top: "370"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "371_prelu"
#   type: "PReLU"
#   bottom: "370"
#   top: "371"
# }
# layer {
#   name: "372"
#   type: "Convolution"
#   bottom: "371"
#   top: "372"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "373_bn"
#   type: "BatchNorm"
#   bottom: "372"
#   top: "373"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "373_bn_scale"
#   type: "Scale"
#   bottom: "373"
#   top: "373"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "374"
#   type: "Eltwise"
#   bottom: "365"
#   bottom: "373"
#   top: "374"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "375"
#   type: "Convolution"
#   bottom: "374"
#   top: "375"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "376_bn"
#   type: "BatchNorm"
#   bottom: "375"
#   top: "376"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "376_bn_scale"
#   type: "Scale"
#   bottom: "376"
#   top: "376"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "377_prelu"
#   type: "PReLU"
#   bottom: "376"
#   top: "377"
# }
# layer {
#   name: "378"
#   type: "Convolution"
#   bottom: "377"
#   top: "378"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 128
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "379_bn"
#   type: "BatchNorm"
#   bottom: "378"
#   top: "379"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "379_bn_scale"
#   type: "Scale"
#   bottom: "379"
#   top: "379"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "380_prelu"
#   type: "PReLU"
#   bottom: "379"
#   top: "380"
# }
# layer {
#   name: "381"
#   type: "Convolution"
#   bottom: "380"
#   top: "381"
#   convolution_param {
#     num_output: 64
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "382_bn"
#   type: "BatchNorm"
#   bottom: "381"
#   top: "382"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "382_bn_scale"
#   type: "Scale"
#   bottom: "382"
#   top: "382"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "383"
#   type: "Eltwise"
#   bottom: "374"
#   bottom: "382"
#   top: "383"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "384"
#   type: "Convolution"
#   bottom: "383"
#   top: "384"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "385_bn"
#   type: "BatchNorm"
#   bottom: "384"
#   top: "385"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "385_bn_scale"
#   type: "Scale"
#   bottom: "385"
#   top: "385"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "386_prelu"
#   type: "PReLU"
#   bottom: "385"
#   top: "386"
# }
# layer {
#   name: "387"
#   type: "Convolution"
#   bottom: "386"
#   top: "387"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 2
#     stride_w: 2
#     dilation: 1
#   }
# }
# layer {
#   name: "388_bn"
#   type: "BatchNorm"
#   bottom: "387"
#   top: "388"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "388_bn_scale"
#   type: "Scale"
#   bottom: "388"
#   top: "388"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "389_prelu"
#   type: "PReLU"
#   bottom: "388"
#   top: "389"
# }
# layer {
#   name: "390"
#   type: "Convolution"
#   bottom: "389"
#   top: "390"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "391_bn"
#   type: "BatchNorm"
#   bottom: "390"
#   top: "391"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "391_bn_scale"
#   type: "Scale"
#   bottom: "391"
#   top: "391"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "392"
#   type: "Convolution"
#   bottom: "391"
#   top: "392"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "393_bn"
#   type: "BatchNorm"
#   bottom: "392"
#   top: "393"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "393_bn_scale"
#   type: "Scale"
#   bottom: "393"
#   top: "393"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "394_prelu"
#   type: "PReLU"
#   bottom: "393"
#   top: "394"
# }
# layer {
#   name: "395"
#   type: "Convolution"
#   bottom: "394"
#   top: "395"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "396_bn"
#   type: "BatchNorm"
#   bottom: "395"
#   top: "396"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "396_bn_scale"
#   type: "Scale"
#   bottom: "396"
#   top: "396"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "397_prelu"
#   type: "PReLU"
#   bottom: "396"
#   top: "397"
# }
# layer {
#   name: "398"
#   type: "Convolution"
#   bottom: "397"
#   top: "398"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "399_bn"
#   type: "BatchNorm"
#   bottom: "398"
#   top: "399"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "399_bn_scale"
#   type: "Scale"
#   bottom: "399"
#   top: "399"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "400"
#   type: "Eltwise"
#   bottom: "391"
#   bottom: "399"
#   top: "400"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "401"
#   type: "Convolution"
#   bottom: "400"
#   top: "401"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "402_bn"
#   type: "BatchNorm"
#   bottom: "401"
#   top: "402"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "402_bn_scale"
#   type: "Scale"
#   bottom: "402"
#   top: "402"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "403_prelu"
#   type: "PReLU"
#   bottom: "402"
#   top: "403"
# }
# layer {
#   name: "404"
#   type: "Convolution"
#   bottom: "403"
#   top: "404"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "405_bn"
#   type: "BatchNorm"
#   bottom: "404"
#   top: "405"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "405_bn_scale"
#   type: "Scale"
#   bottom: "405"
#   top: "405"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "406_prelu"
#   type: "PReLU"
#   bottom: "405"
#   top: "406"
# }
# layer {
#   name: "407"
#   type: "Convolution"
#   bottom: "406"
#   top: "407"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "408_bn"
#   type: "BatchNorm"
#   bottom: "407"
#   top: "408"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "408_bn_scale"
#   type: "Scale"
#   bottom: "408"
#   top: "408"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "409"
#   type: "Eltwise"
#   bottom: "400"
#   bottom: "408"
#   top: "409"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "410"
#   type: "Convolution"
#   bottom: "409"
#   top: "410"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "411_bn"
#   type: "BatchNorm"
#   bottom: "410"
#   top: "411"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "411_bn_scale"
#   type: "Scale"
#   bottom: "411"
#   top: "411"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "412_prelu"
#   type: "PReLU"
#   bottom: "411"
#   top: "412"
# }
# layer {
#   name: "413"
#   type: "Convolution"
#   bottom: "412"
#   top: "413"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "414_bn"
#   type: "BatchNorm"
#   bottom: "413"
#   top: "414"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "414_bn_scale"
#   type: "Scale"
#   bottom: "414"
#   top: "414"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "415_prelu"
#   type: "PReLU"
#   bottom: "414"
#   top: "415"
# }
# layer {
#   name: "416"
#   type: "Convolution"
#   bottom: "415"
#   top: "416"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "417_bn"
#   type: "BatchNorm"
#   bottom: "416"
#   top: "417"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "417_bn_scale"
#   type: "Scale"
#   bottom: "417"
#   top: "417"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "418"
#   type: "Eltwise"
#   bottom: "409"
#   bottom: "417"
#   top: "418"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "419"
#   type: "Convolution"
#   bottom: "418"
#   top: "419"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "420_bn"
#   type: "BatchNorm"
#   bottom: "419"
#   top: "420"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "420_bn_scale"
#   type: "Scale"
#   bottom: "420"
#   top: "420"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "421_prelu"
#   type: "PReLU"
#   bottom: "420"
#   top: "421"
# }
# layer {
#   name: "422"
#   type: "Convolution"
#   bottom: "421"
#   top: "422"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "423_bn"
#   type: "BatchNorm"
#   bottom: "422"
#   top: "423"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "423_bn_scale"
#   type: "Scale"
#   bottom: "423"
#   top: "423"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "424_prelu"
#   type: "PReLU"
#   bottom: "423"
#   top: "424"
# }
# layer {
#   name: "425"
#   type: "Convolution"
#   bottom: "424"
#   top: "425"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "426_bn"
#   type: "BatchNorm"
#   bottom: "425"
#   top: "426"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "426_bn_scale"
#   type: "Scale"
#   bottom: "426"
#   top: "426"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "427"
#   type: "Eltwise"
#   bottom: "418"
#   bottom: "426"
#   top: "427"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "428"
#   type: "Convolution"
#   bottom: "427"
#   top: "428"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "429_bn"
#   type: "BatchNorm"
#   bottom: "428"
#   top: "429"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "429_bn_scale"
#   type: "Scale"
#   bottom: "429"
#   top: "429"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "430_prelu"
#   type: "PReLU"
#   bottom: "429"
#   top: "430"
# }
# layer {
#   name: "431"
#   type: "Convolution"
#   bottom: "430"
#   top: "431"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "432_bn"
#   type: "BatchNorm"
#   bottom: "431"
#   top: "432"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "432_bn_scale"
#   type: "Scale"
#   bottom: "432"
#   top: "432"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "433_prelu"
#   type: "PReLU"
#   bottom: "432"
#   top: "433"
# }
# layer {
#   name: "434"
#   type: "Convolution"
#   bottom: "433"
#   top: "434"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "435_bn"
#   type: "BatchNorm"
#   bottom: "434"
#   top: "435"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "435_bn_scale"
#   type: "Scale"
#   bottom: "435"
#   top: "435"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "436"
#   type: "Eltwise"
#   bottom: "427"
#   bottom: "435"
#   top: "436"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "437"
#   type: "Convolution"
#   bottom: "436"
#   top: "437"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "438_bn"
#   type: "BatchNorm"
#   bottom: "437"
#   top: "438"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "438_bn_scale"
#   type: "Scale"
#   bottom: "438"
#   top: "438"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "439_prelu"
#   type: "PReLU"
#   bottom: "438"
#   top: "439"
# }
# layer {
#   name: "440"
#   type: "Convolution"
#   bottom: "439"
#   top: "440"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "441_bn"
#   type: "BatchNorm"
#   bottom: "440"
#   top: "441"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "441_bn_scale"
#   type: "Scale"
#   bottom: "441"
#   top: "441"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "442_prelu"
#   type: "PReLU"
#   bottom: "441"
#   top: "442"
# }
# layer {
#   name: "443"
#   type: "Convolution"
#   bottom: "442"
#   top: "443"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "444_bn"
#   type: "BatchNorm"
#   bottom: "443"
#   top: "444"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "444_bn_scale"
#   type: "Scale"
#   bottom: "444"
#   top: "444"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "445"
#   type: "Eltwise"
#   bottom: "436"
#   bottom: "444"
#   top: "445"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "446"
#   type: "Convolution"
#   bottom: "445"
#   top: "446"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "447_bn"
#   type: "BatchNorm"
#   bottom: "446"
#   top: "447"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "447_bn_scale"
#   type: "Scale"
#   bottom: "447"
#   top: "447"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "448_prelu"
#   type: "PReLU"
#   bottom: "447"
#   top: "448"
# }
# layer {
#   name: "449"
#   type: "Convolution"
#   bottom: "448"
#   top: "449"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     group: 512
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 2
#     stride_w: 2
#     dilation: 1
#   }
# }
# layer {
#   name: "450_bn"
#   type: "BatchNorm"
#   bottom: "449"
#   top: "450"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "450_bn_scale"
#   type: "Scale"
#   bottom: "450"
#   top: "450"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "451_prelu"
#   type: "PReLU"
#   bottom: "450"
#   top: "451"
# }
# layer {
#   name: "452"
#   type: "Convolution"
#   bottom: "451"
#   top: "452"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "453_bn"
#   type: "BatchNorm"
#   bottom: "452"
#   top: "453"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "453_bn_scale"
#   type: "Scale"
#   bottom: "453"
#   top: "453"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "454"
#   type: "Convolution"
#   bottom: "453"
#   top: "454"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "455_bn"
#   type: "BatchNorm"
#   bottom: "454"
#   top: "455"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "455_bn_scale"
#   type: "Scale"
#   bottom: "455"
#   top: "455"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "456_prelu"
#   type: "PReLU"
#   bottom: "455"
#   top: "456"
# }
# layer {
#   name: "457"
#   type: "Convolution"
#   bottom: "456"
#   top: "457"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "458_bn"
#   type: "BatchNorm"
#   bottom: "457"
#   top: "458"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "458_bn_scale"
#   type: "Scale"
#   bottom: "458"
#   top: "458"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "459_prelu"
#   type: "PReLU"
#   bottom: "458"
#   top: "459"
# }
# layer {
#   name: "460"
#   type: "Convolution"
#   bottom: "459"
#   top: "460"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "461_bn"
#   type: "BatchNorm"
#   bottom: "460"
#   top: "461"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "461_bn_scale"
#   type: "Scale"
#   bottom: "461"
#   top: "461"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "462"
#   type: "Eltwise"
#   bottom: "453"
#   bottom: "461"
#   top: "462"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "463"
#   type: "Convolution"
#   bottom: "462"
#   top: "463"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "464_bn"
#   type: "BatchNorm"
#   bottom: "463"
#   top: "464"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "464_bn_scale"
#   type: "Scale"
#   bottom: "464"
#   top: "464"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "465_prelu"
#   type: "PReLU"
#   bottom: "464"
#   top: "465"
# }
# layer {
#   name: "466"
#   type: "Convolution"
#   bottom: "465"
#   top: "466"
#   convolution_param {
#     num_output: 256
#     bias_term: false
#     group: 256
#     pad_h: 1
#     pad_w: 1
#     kernel_h: 3
#     kernel_w: 3
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "467_bn"
#   type: "BatchNorm"
#   bottom: "466"
#   top: "467"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "467_bn_scale"
#   type: "Scale"
#   bottom: "467"
#   top: "467"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "468_prelu"
#   type: "PReLU"
#   bottom: "467"
#   top: "468"
# }
# layer {
#   name: "469"
#   type: "Convolution"
#   bottom: "468"
#   top: "469"
#   convolution_param {
#     num_output: 128
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "470_bn"
#   type: "BatchNorm"
#   bottom: "469"
#   top: "470"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "470_bn_scale"
#   type: "Scale"
#   bottom: "470"
#   top: "470"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "471"
#   type: "Eltwise"
#   bottom: "462"
#   bottom: "470"
#   top: "471"
#   eltwise_param {
#     operation: SUM
#   }
# }
# layer {
#   name: "472"
#   type: "Convolution"
#   bottom: "471"
#   top: "472"
#   convolution_param {
#     num_output: 512
#     bias_term: false
#     group: 1
#     pad_h: 0
#     pad_w: 0
#     kernel_h: 1
#     kernel_w: 1
#     stride_h: 1
#     stride_w: 1
#     dilation: 1
#   }
# }
# layer {
#   name: "473_bn"
#   type: "BatchNorm"
#   bottom: "472"
#   top: "473"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "473_bn_scale"
#   type: "Scale"
#   bottom: "473"
#   top: "473"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "474_prelu"
#   type: "PReLU"
#   bottom: "473"
#   top: "474"
# }
# layer {
#   name: "bn1"
#   type: "BatchNorm"
#   bottom: "474"
#   top: "475"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "bn1_scale_bn_scale"
#   type: "Scale"
#   bottom: "475"
#   top: "475"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "fc_emb"
#   type: "InnerProduct"
#   bottom: "475"
#   top: "476"
#   param {
#     lr_mult: 1.0
#     decay_mult: 1.0
#   }
#   param {
#     lr_mult: 2.0
#     decay_mult: 0.0
#   }
#   inner_product_param {
#     num_output: 512
#   }
# }
# layer {
#   name: "bn2"
#   type: "BatchNorm"
#   bottom: "476"
#   top: "477"
#   batch_norm_param {
#     use_global_stats: true
#     eps: 9.99999974738e-06
#   }
# }
# layer {
#   name: "bn2_scale_bn_scale"
#   type: "Scale"
#   bottom: "477"
#   top: "477"
#   scale_param {
#     bias_term: true
#   }
# }

# %%
for i in self.graph.as_graph_def().node:
    print("{:45} {:20}".format(i.name, i.op))
# Out:
# [name: "335_bn"
#  type: "BatchNorm"
#  bottom: "334"
#  top: "335"
#  batch_norm_param {
#    use_global_stats: true
#    eps: 9.99999974738e-06
#  }]

# %% [markdown]
# ### dummy add layer

# %%
import sys
sys.path.insert(0, "/home/allen/Documents/caffe/python")
import caffe
import numpy as np

import caffe.proto.caffe_pb2 as caffepb
from google.protobuf import text_format
import tensorflow as tf

# %%
data = tf.placeholder(tf.float32, shape=[1,112,112,3], name='input')
with tf.variable_scope(name_or_scope="{}/".format("test"), default_name='ha'):
    v1 = tf.compat.v1.get_variable("v1", shape=[1,112,112,3], trainable=False)
    v1 = tf.identity(v1, name='add_element')
    v3 = tf.compat.v1.add(v1, data)
# v3 = v1 + data
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0916 10:57:46.214848 139994486486784 deprecation.py:506] From /home/allen/.pyenv/versions/2.7.10/envs/py2710/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
graph = tf.get_default_graph()
for i in graph.as_graph_def().node:
    print("{:45} {:20}".format(i.name, i.op))
# Out:
# input                                         Placeholder
# test//v1/Initializer/random_uniform/shape     Const
# test//v1/Initializer/random_uniform/min       Const
# test//v1/Initializer/random_uniform/max       Const
# test//v1/Initializer/random_uniform/RandomUniform RandomUniform
# test//v1/Initializer/random_uniform/sub       Sub
# test//v1/Initializer/random_uniform/mul       Mul
# test//v1/Initializer/random_uniform           Add
# test//v1                                      VariableV2
# test//v1/Assign                               Assign
# test//v1/read                                 Identity
# test/add_element                              Identity
# test/Add                                      Add

# %%
var_data_map = {}
sess = tf.Session()
var_data_map['v1'] = np.ones((1,112,112,3))
for name in var_data_map.keys():
    with tf.compat.v1.variable_scope("", reuse=True):
        data = var_data_map[name]
        var = tf.compat.v1.get_variable(name)
        sess.run(var.assign(data))

# %%
model_name = "add_identity"
# output_name = "fc2,fc3,fc4"
output_name = "Add"

saver = tf.compat.v1.train.Saver()
saver.save(sess, "./output/{}.ckpt".format(model_name))
# Out:
# './output/add_identity.ckpt'

# %%
with tf.io.gfile.GFile('./output/{}.pb'.format(model_name), 'wb') as f:
    f.write(sess.graph_def.SerializeToString())

# %%
from tensorflow.python.tools.freeze_graph import freeze_graph
d = freeze_graph("./output/{}.pb".format(model_name), "",
             True, "./output/{}.ckpt".format(model_name),
             output_name, 'save/restore_all',
             'save/Const:0', "./output/frozen_{}.pb".format(model_name),
             True, '')
# Out:
# W0916 10:04:44.320305 140689036867328 deprecation.py:323] From /home/allen/.pyenv/versions/2.7.10/envs/py2710/lib/python2.7/site-packages/tensorflow/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0916 10:04:44.347702 140689036867328 deprecation.py:323] From /home/allen/.pyenv/versions/2.7.10/envs/py2710/lib/python2.7/site-packages/tensorflow/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0916 10:04:44.349272 140689036867328 deprecation.py:323] From /home/allen/.pyenv/versions/2.7.10/envs/py2710/lib/python2.7/site-packages/tensorflow/python/framework/graph_util_impl.py:270: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`

# %%
# deploy = "/media/allen/mass/caffe-tensorflow/mobilenet_multitask_20190322.temp.cp.prototxt"
# caffemodel = "/media/allen/mass/caffe-tensorflow/mobilenet_multitask_20190322.temp.caffemodel"
deploy = "/media/allen/mass/deep-learning-works/caffe_models/GAE.prototxt"
caffemodel = "/media/allen/mass/deep-learning-works/caffe_models/GAE.caffemodel"
# net = caffe.Net(deploy, caffemodel, caffe.TEST)

# net_params = caffepb.NetParameter()
# f = open(deploy, 'rb')
# net_str = f.read()
# text_format.Merge(net_str, net_params)

class Network():
    def __init__(self, deploy, caffemodel, name=None):
        
        net_params = caffepb.NetParameter()
        f = open(deploy, 'rb')
        net_str = f.read()
        text_format.Merge(net_str, net_params)

        self.weights = caffe.Net(deploy, caffemodel, caffe.TEST).params
        self.caffe_graph = net_params
        
        self.caffe_layer_list = {}
        self.set_caffe_layer_list()
        
        self.sess = tf.InteractiveSession()
        self.graph = self.sess.graph
        self.end_points = {}
        self.var_data_map = {}
        self.residual_block_idx = 1
        self.conv_block_idx = 0
        self.fc_idx = 0
        self.model_name = name if name is not None else ""
        self.scope = self.model_name
        
    def show_graph(self):
        for i in self.graph.as_graph_def().node:
            print("{:45} {:20}".format(i.name, i.op))
        
    def set_caffe_layer_list(self):
        for layer in self.caffe_graph.layer:
            self.caffe_layer_list[layer.name] = layer
        
    def get_layer(self, l_name, level='next'):
        next_layers = []
        if level == 'next':
            tops = self.caffe_layer_list[l_name].top
            for layer in self.caffe_graph.layer:
                for top_name in tops:
                    if top_name in layer.bottom:
#                         if self.caffe_layer_list[l_name].type == 'Convolution':
#                             if layer.type == 'ReLU' or layer.type == 'Convolution':
#                                 continue
                        next_layers.append(layer)
            if len(tops) > 1:
                return next_layers
            
        else:
            bottoms = self.caffe_layer_list[l_name].bottom
            for layer in self.caffe_graph.layer:
                for bottom_name in bottoms:
                    if bottom_name in layer.top:
#                         if self.caffe_layer_list[l_name].type == 'ReLU' or self.caffe_layer_list[l_name].type == 'Convolution':
#                             if layer.type == 'ReLU' or layer.type == 'Convolution':
#                                 continue
                        next_layers.append(layer)
            if len(bottoms) > 1:
                return next_layers
    
        if level == 'next':
            for i, layer in enumerate(next_layers):
                if l_name == layer.name:
                    return next_layers[i+1]
            return next_layers[0]
        else:
            for i, layer in enumerate(next_layers):
                if l_name == layer.name:
                    return next_layers[i-1]
            return next_layers[-1]
           
    
    def break_bn_scale(self):
        for layer in self.caffe_graph.layer:
            if layer.type == 'BatchNorm':
                layer.top[0] += "_bn"
            if layer.type == 'Scale':
                layer.bottom[0] += "_bn"
    
    def make_tf_variable(self, name, data, prefix=None):
        if prefix is not None:
            name = prefix + "/" + name
        self.var_data_map[name] = data
        return tf.compat.v1.get_variable(name, data.shape, trainable=False)
#         return tf.constant(value=weight, dtype=tf.float32)        
    
    def add_end_points(self, l, output):
        self.end_points[l.name] = output
               
        
    def add(self, l):   
        print(l.name)
        if l.type == 'Input':
            with tf.variable_scope(name_or_scope=self.scope):
                n, c, h, w = l.input_param.shape[0].dim
                shape = [n, h, w, c]
                output = tf.placeholder(tf.float32, shape=shape, name=l.name)
                self.add_end_points(l, output)
            
        elif l.type == 'BatchNorm':    
            scope = "{}/{}".format(self.scope, l.type)
            scale_layer = self.get_layer(l.name)            
            w1 = self.weights[l.name]
            raw_mean = w1[0].data
            raw_var = w1[1].data
            w2 = self.weights[scale_layer.name]
            raw_scale = w2[0].data
            raw_offset = w2[1].data
            
            bottom = self.get_layer(l.name, level='prev')
            inputs = self.end_points[bottom.name]
            input_shape = inputs.get_shape()
            mean = self.make_tf_variable(l.name+'_mean', raw_mean, scope)
            var = self.make_tf_variable(l.name+'_var', raw_var, scope)
            scale = self.make_tf_variable(l.name+'_scale', raw_scale, scope)
            offset = self.make_tf_variable(l.name+'_offset', raw_offset, scope)
            with tf.variable_scope(name_or_scope=scope):
                if len(input_shape) == 2:
                    inputs = tf.reshape(inputs, shape=[input_shape[0], 1, 1, input_shape[1]], name=l.name+"_expand")          
                    output = tf.nn.fused_batch_norm(x=inputs, scale=scale, offset=offset, mean=mean, variance=var, is_training=False, name=l.name)[0]
                    output = tf.reshape(output, shape=[input_shape[0], input_shape[1]], name=l.name+"_reduce")  
                    output = tf.identity(output, name='output')
                else:
                    output = tf.nn.fused_batch_norm(x=inputs, scale=scale, offset=offset, mean=mean, variance=var, is_training=False, name=l.name)[0]
                    output = tf.identity(output, name='output')
            self.add_end_points(scale_layer, output)
        
        elif l.type == 'Convolution':     
            self.conv_block_idx += 1
            self.scope = "{}/block{}/conv{}".format(self.model_name, self.residual_block_idx, self.conv_block_idx)
            params = l.convolution_param
            c_o = params.num_output
            bias = params.bias_term
            group = params.group
            p_h = params.pad_h
            p_w = params.pad_w
            k_h = params.kernel_h
            k_w = params.kernel_w
            s_h = params.stride_h
            s_w = params.stride_w
            dilation = params.dilation
            
            if s_h == 0 or s_w == 0:
                if len(params.stride) == 0:
                    s_h = s_w = 1
                else:
                    s_h = s_w = params.stride[0]
            if k_h == 0 or k_w == 0:
                k_h = k_w = params.kernel_size[0]
            if len(params.pad) > 0 and params.pad[0] > 0:
                p_h = p_w = params.pad[0]
                
            bottom = self.get_layer(l.name, level='prev')
            inputs = self.end_points[bottom.name]
            input_shape = inputs.get_shape()
            
            assert len(input_shape) == 4
            _, _, _, c_i = input_shape
            
            
                    
            raw_w = self.weights[l.name][0].data
            if group == 1:
                raw_w = raw_w.transpose((2, 3, 1, 0))                
                kernel = self.make_tf_variable(l.name+'_conv', raw_w, self.scope)
                with tf.variable_scope(name_or_scope=self.scope):
                    if p_h > 0:
                        inputs = tf.pad(inputs, [[0, 0], [p_h, p_h], [p_w, p_w], [0, 0]], name="{}_pad".format(l.name))
                        pad_type = 'VALID'
                    else:
                        if s_h > 1:
                            pad_type = 'SAME'
                        else:
                            pad_type = 'VALID'
                    output = tf.nn.conv2d(inputs, filter=kernel, strides=[1, s_h, s_w, 1], padding=pad_type, name=l.name)
                    output = tf.identity(output, name='output')
            elif group == c_i and group == c_o:                
                raw_w = raw_w.transpose((2, 3, 0, 1))
                kernel = self.make_tf_variable(l.name+'_conv', raw_w, self.scope)
                with tf.variable_scope(name_or_scope=self.scope):
                    if p_h > 0:
                        inputs = tf.pad(inputs, [[0, 0], [p_h, p_h], [p_w, p_w], [0, 0]], name="{}_pad".format(l.name))
                        pad_type = 'VALID'
                    else:
                        if s_h > 1:
                            pad_type = 'SAME'
                        else:
                            pad_type = 'VALID'
                    output = tf.nn.depthwise_conv2d(inputs, filter=kernel, strides=[1,s_h, s_w,1], rate=[1,1], padding=pad_type, name=l.name)
                    output = tf.identity(output, name='output')
            else:
                raw_w = raw_w.transpose((2, 3, 1, 0))
                kernel = self.make_tf_variable(l.name+'_conv', raw_w, self.scope)
                with tf.variable_scope(name_or_scope=self.scope):
                    if p_h > 0:
                        inputs = tf.pad(inputs, [[0, 0], [p_h, p_h], [p_w, p_w], [0, 0]], name="{}_pad".format(l.name))
                        pad_type = 'VALID'
                    else:
                        if s_h > 1:
                            pad_type = 'SAME'
                        else:
                            pad_type = 'VALID'
                    # Split the input into groups and then convolve each of them independently
                    input_groups = tf.split(axis=3, num_or_size_splits=group, value=inputs)
                    kernel_groups = tf.split(axis=3, num_or_size_splits=group, value=kernel)
                    convolve = lambda i, k: tf.nn.conv2d(i, k, [1, s_h, s_w, 1], padding=pad_type)
                    output_groups = [convolve(i, k) for i, k in zip(input_groups, kernel_groups)]
                    # Concatenate the groups
                    output = tf.compat.v1.concat(values=output_groups, axis=3)
                    output = tf.identity(output, name='output')
                
            if bias:
                raw_b = self.weights[l.name][1].data
                biases = self.make_tf_variable(l.name+'_bias', raw_b, self.scope)
                with tf.variable_scope(name_or_scope=self.scope):
                    output = tf.nn.bias_add(output, biases, name=l.name+"_bias")        
                    output = tf.identity(output, name='output')
            self.add_end_points(l, output)
        
        elif l.type == 'ReLU' or l.type == 'PReLU':
            scope = "{}/{}".format(self.scope, l.type)
            bottom = self.get_layer(l.name, level='prev')
            inputs = self.end_points[bottom.name]
            with tf.variable_scope(name_or_scope=scope):
                output = tf.nn.relu(inputs, name=l.name)
                output = tf.identity(output, name='output')
            self.add_end_points(l, output)
        
#         elif l.type == 'PReLU':
#             bottom = self.get_layer(l.name, level='prev')[-1]
#             inputs = self.end_points[bottom.name]
#             raw_alpha = self.weights[l.name][0].data
#             alpha = self.make_tf_variable(l.name+"_alpha", raw_alpha)  
#             with tf.compat.v1.variable_scope(l.name, values=[inputs]) as scope:
#                 output = tf.nn.relu(inputs) + tf.multiply(alpha, (inputs - tf.abs(inputs))) * 0.5
#             self.add_end_points(l, output)
        
        elif l.type == 'InnerProduct':
            self.fc_idx += 1
            self.scope = "{}/fc{}".format(self.model_name, self.fc_idx)
            params = l.inner_product_param
            c_o = params.num_output
            bias = params.bias_term
            
            bottom = self.get_layer(l.name, level='prev')
            inputs = self.end_points[bottom.name]
            input_shape = inputs.get_shape()            
            
            raw_w = self.weights[l.name][0].data
            raw_w = raw_w.transpose((1,0))
            if bias:
                raw_b = self.weights[l.name][1].data
            else:
                raw_b = np.zeros(c_o)
                
            weights = self.make_tf_variable(l.name+'_fc_w', raw_w, self.scope)
            biases = self.make_tf_variable(l.name+'_fc_b', raw_b, self.scope)
            with tf.variable_scope(name_or_scope=self.scope):
                if len(input_shape) == 4:
                    n, h, w, c = input_shape 
                    c_i = h*w*c
                    inputs = tf.reshape(inputs, shape=[1, c_i])
                else:
                    n, c_i = input_shape
                output = tf.compat.v1.nn.xw_plus_b(x=inputs, weights=weights, biases=biases, name=l.name)
                output = tf.identity(output, name='output')
            self.add_end_points(l, output)
            
        elif l.type == 'Scale':
            print("Merge into BN")
            
        elif l.type == 'Eltwise':
            self.residual_block_idx += 1
            self.conv_block_idx = 0
            self.scope = "{}/block{}".format(self.model_name, self.residual_block_idx)
            bottoms = self.get_layer(l.name, level='prev')
            output = None
            op = l.eltwise_param.operation
            if op == 1:
                with tf.variable_scope(name_or_scope=self.scope):
                    for i, bottom in enumerate(bottoms):
                        if bottom.type == 'BatchNorm':
                            continue
                        if output is None:
                            output = self.end_points[bottom.name]
                        else:
                            output += self.end_points[bottom.name]
                            output = tf.identity(output, name='output')
            else:
                print("Unsupported layer {}/{} at {}".format(l.type, op, l.name))
                sys.exit(1)
            self.add_end_points(l, output)
        elif l.type == 'Pooling':
            scope = "{}/{}".format(self.scope, l.type)
            bottom = self.get_layer(l.name, level='prev')
            inputs = self.end_points[bottom.name]
            
            params = l.pooling_param
            p_h = params.pad_h
            p_w = params.pad_w
            k_size = params.kernel_size
            if params.global_pooling:
                input_shape = inputs.get_shape()
                k_size = input_shape[1]
            s = params.stride           
            op = params.pool   
            '''
            enum PoolMethod {
                MAX = 0;
                AVE = 1;
                STOCHASTIC = 2;
              }
            '''
            with tf.variable_scope(name_or_scope=scope):
                if p_h > 0:
                    inputs = tf.pad(inputs, [[0, 0], [p_h, p_h], [p_w, p_w], [0, 0]], name="{}_pad".format(l.name))
                    pad_type = 'VALID'
                else:
                    if s > 1:
                        pad_type = 'SAME'
                    else:
                        pad_type = 'VALID'

                if op == 0:
                    output = tf.nn.max_pool2d(inputs, ksize=[1, k_size, k_size, 1], strides=[1, s, s, 1], padding=pad_type, name=l.name)
                if op == 1:
                    output = tf.nn.avg_pool2d(inputs, ksize=[1, k_size, k_size, 1], strides=[1, s, s, 1], padding=pad_type, name=l.name)
                
                output = tf.identity(output, name='output')
                
            self.add_end_points(l, output)
            
        elif l.type == 'Sigmoid':
            scope = "{}/{}".format(self.scope, l.type)
            bottom = self.get_layer(l.name, level='prev')
            inputs = self.end_points[bottom.name]
            input_shape = inputs.get_shape()
            with tf.variable_scope(name_or_scope=scope):
                if len(input_shape) == 4 and input_shape[1] == input_shape[2] == 1:
                    inputs = tf.reshape(inputs, shape=[input_shape[0], input_shape[3]], name=l.name+"_flatten")
                output = tf.nn.sigmoid(inputs, name=l.name)
                output = tf.identity(output, name='output')
            self.add_end_points(l, output)
            
        elif l.type == 'Flatten':
            axis = l.flatten_param.axis
            assert axis == 1
            scope = "{}/{}".format(self.scope, l.type)
            bottom = self.get_layer(l.name, level='prev')
            inputs = self.end_points[bottom.name]
            input_shape = inputs.get_shape()
            with tf.variable_scope(name_or_scope=scope):
                output = tf.reshape(inputs, shape=[input_shape[0], input_shape[1]*input_shape[2]*input_shape[3]], name=l.name)
                output = tf.identity(output, name='output')
            self.add_end_points(l, output)
            
        else:
            print("Unsupported layer {} at {}".format(l.type, l.name))
            sys.exit(1)
            
    def build(self, flag=None):
        for layer in self.caffe_graph.layer:
            self.add(layer)
            if flag is not None:
                if layer.name == flag:
                    break
    
    def allocate_weights(self):
        for name in self.var_data_map.keys():
            with tf.compat.v1.variable_scope("", reuse=True):
                data = self.var_data_map[name]
                var = tf.compat.v1.get_variable(name)
                self.sess.run(var.assign(data))
