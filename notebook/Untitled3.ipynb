# %%
# !pip install lxml, requests
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/ec/be/5ab8abdd8663c0386ec2dd595a5bc0e23330a0549b8a91e32f38c20845b6/lxml-4.4.1-cp36-cp36m-manylinux1_x86_64.whl (5.8MB)
#     100% |████████████████████████████████| 5.8MB 2.5MB/s ta 0:00:011
# Installing collected packages: lxml
# Successfully installed lxml-4.4.1
# You are using pip version 18.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import requests
import pandas as pd
import numpy as np

def financial_statement(year, season, type='綜合損益彙總表'):

    if year >= 1000:
        year -= 1911

    if type == '綜合損益彙總表':
        url = 'https://mops.twse.com.tw/mops/web/t163sb04'
    elif type == '資產負債彙總表':
        url = 'https://mops.twse.com.tw/mops/web/t163sb05'
    elif type == '營益分析彙總表':
        url = 'https://mops.twse.com.tw/mops/web/t163sb06'
    else:
        print('type does not match')

    r = requests.post(url, {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'TYPEK':'sii',
        'year':str(year),
        'season':str(season),
    })

    r.encoding = 'utf8'
    
    dfs = pd.read_html(r.text, header=None)

    return pd.concat(dfs[10:], axis=0, sort=False)\
             .set_index(['公司代號'])\
             .apply(lambda s: pd.to_numeric(s, errors='ignore'))

# %%
df = financial_statement(2018, 1)

# %%
df.head()
# Out:
#        公司名稱      利息淨收益    利息以外淨損益  呆帳費用、承諾及保證責任準備提存       營業費用  \
# 公司代號
# 2801.0   彰銀  5769672.0  2053193.0          340541.0  3820294.0
# 2809.0  京城銀  1231597.0   733170.0          -28436.0   545477.0
# 2812.0  台中銀  2003434.0   717173.0          169921.0  1622599.0
# 2820.0   華票   260005.0   237516.0           -4697.0   117021.0
# 2834.0  臺企銀  4246100.0  1525637.0          356608.0  3296699.0
#
#         繼續營業單位稅前淨利（淨損） 所得稅費用（利益）  繼續營業單位本期稅後淨利（淨損） 停業單位損益 合併前非屬共同控制股權損益  ...  \
# 公司代號                                                                     ...
# 2801.0       3662030.0    233332         3428698.0     --            --  ...
# 2809.0       1447726.0    153418         1294308.0     --            --  ...
# 2812.0        928087.0     47273          880814.0      0            --  ...
# 2820.0        385197.0     50721          334476.0     --            --  ...
# 2834.0       2118430.0    259669         1858761.0      0            --  ...
#
#         保險負債準備淨變動  繼續營業單位稅前損益  所得稅（費用）利益 繼續營業單位稅前純益（純損） 繼續營業單位本期純益（純損）  \
# 公司代號
# 2801.0        NaN         NaN        NaN            NaN            NaN
# 2809.0        NaN         NaN        NaN            NaN            NaN
# 2812.0        NaN         NaN        NaN            NaN            NaN
# 2820.0        NaN         NaN        NaN            NaN            NaN
# 2834.0        NaN         NaN        NaN            NaN            NaN
#
#        其他綜合損益（稅後淨額）  收入  支出 其他綜合損益  \
# 公司代號
# 2801.0          NaN NaN NaN    NaN
# 2809.0          NaN NaN NaN    NaN
# 2812.0          NaN NaN NaN    NaN
# 2820.0          NaN NaN NaN    NaN
# 2834.0          NaN NaN NaN    NaN
#
#         電子投票│  不繼續公開發行│  市場公告│  公司治理評鑑│  網站地圖│  網站使用說明  投資人服務中心(02)2792-8188 聯絡我們
# 公司代號
# 2801.0                                                NaN
# 2809.0                                                NaN
# 2812.0                                                NaN
# 2820.0                                                NaN
# 2834.0                                                NaN
#
# [5 rows x 57 columns]
